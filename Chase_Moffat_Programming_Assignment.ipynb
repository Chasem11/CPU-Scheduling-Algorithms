# %%
"""
The process class stores each processes CPU and I/O bursts, process id, total burst time,
wait time, turnaround time, and response time.
"""
class Process:

    def __init__(self, pid, bursts):
        self.pid = pid
        self.bursts = bursts
        #Total burst time to calculate wait time
        self.total_burst_time = sum(bursts)
        self.wait_time = 0
        self.turnaround_time = 0
        #Set to 1 initially
        self.response_time = 1

P1 = Process(1, [5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])
P2 = Process(2, [4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])
P3 = Process(3, [8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])
P4 = Process(4, [3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])
P5 = Process(5, [16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])
P6 = Process(6, [11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])
P7 = Process(7, [14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])
P8 = Process(8, [4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])

processes = [P1, P2, P3, P4, P5, P6, P7, P8]

#Total for cpu bursts to later calculate cpu utilization
burst_time = 553

# %% [markdown]
# First Come First Serve (non-preemptive)

# %%
def fcfs(processes):
    clock = 0
    ready_queue = processes.copy()  #Initialzes a copy of all processes that start in the ready queue
    io_queue = []
    running_process = 0  #0 means no process is running
    running_time = 0

    def printExecution():
      print(f"Clock: {clock}")

      if running_process == 0:
          print("Running Process: None")
      else:
          print(f"Running Process: P{running_process.pid} Burst Time: {running_process.bursts[0]}")

      print("Ready Queue:", [f"P{p.pid}({p.bursts})" for p in ready_queue])
      print("I/O Queue:", [f"P{p[0].pid}({p[1]})" for p in io_queue])
      print("\n")

    #checks if there are processes in ready queue, io queue, or if a process is currently running
    while len(ready_queue) > 0 or len(io_queue) > 0 or running_process != 0:
        printExecution()

      #If a process is running, running time gets incremented
        if running_process != 0:
            running_time += 1
            #If the run time equals the burst value it removes the process
            if running_time == running_process.bursts[0]:
                running_process.bursts.pop(0)
                #if a process finishes its cpu burst and still has values, it gets sent to the io queue
                if running_process.bursts:
                    io_time = running_process.bursts.pop(0)
                    #adds the process and their io burst value to the io queue
                    io_queue.append((running_process, io_time))
                #else the process has finished
                else:
                    running_process.turnaround_time = clock
                    print(f"Process P{running_process.pid} has completed its total execution.")
                #resets the run time and running process
                running_process = 0
                running_time = 0

        #Checks if there are not processes currently running
        #Also checks if there are processes in the ready queue
        if running_process == 0 and len(ready_queue) > 0:
          #Sets the next process in the queue to run its cpu burst
            running_process = ready_queue.pop(0)
            running_time = 0

            if running_process.response_time == 1:
              #All processes are initialized with a response time of 1
              #This then sets the response time to the clock value if its their first time running
                running_process.response_time = clock

        #creates a new io queue
        new_io_queue = []
        #checks if a process still has time left for its io burst
        for p, time_left in io_queue:
            time_left -= 1
            #once a process has finished it is sent back to ready queue
            if time_left == 0:
                ready_queue.append(p)
            #else the remaining processes are added to a new queue to finish their io bursts
            else:
                new_io_queue.append((p, time_left))
        #remakes the io queue and increments the clock by 1
        io_queue = new_io_queue
        clock += 1

    #Calculates wait time for all processes
    for p in processes:
        p.wait_time = p.turnaround_time - p.total_burst_time
    #returns each process instance and the final run time
    return processes, clock


#Generates all the final results and prints them to the terminal
def generateStats(processData, clock):
  #prints all the final stats
    avg_wait_time = sum(p.wait_time for p in processes) / 8
    avg_turnaround_time = sum(p.turnaround_time for p in processes) / 8
    avg_response_time = sum(p.response_time for p in processes) / 8
    #burst_time is the sum of all the cpu bursts
    cpu_utilization = ( burst_time / clock)

    print("Process\tWaiting Time\tTurnaround Time\tResponse Time")
    for p in processData:
        print(f"P{p.pid}\t{p.wait_time}\t\t{p.turnaround_time}\t\t{p.response_time}")
    print(f"\nAverage Waiting Time: {avg_wait_time}")
    print(f"Average Turnaround Time: {avg_turnaround_time}")
    print(f"Average Response Time: {avg_response_time}")
    print(f"CPU Utilization: {cpu_utilization}%")
    print(f"Total Run Time: {clock}")

if __name__ == "__main__":
    processData, clock = fcfs(processes)
    generateStats(processData, clock)
# Out:
# Clock: 0
# Running Process: None
# Ready Queue: ['P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: []
#
#
# Clock: 1
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: []
#
#
# Clock: 2
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: []
#
#
# Clock: 3
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: []
#
#
# Clock: 4
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: []
#
#
# Clock: 5
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: []
#
#
# Clock: 6
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(26)']
#
#
# Clock: 7
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(25)']
#
#
# Clock: 8
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(24)']
#
#
# Clock: 9
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(23)']
#
#
# Clock: 10
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(22)', 'P2(47)']
#
#
# Clock: 11
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(21)', 'P2(46)']
#
#
# Clock: 12
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(20)', 'P2(45)']
#
#
# Clock: 13
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(19)', 'P2(44)']
#
#
# Clock: 14
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(18)', 'P2(43)']
#
#
# Clock: 15
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(17)', 'P2(42)']
#
#
# Clock: 16
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(16)', 'P2(41)']
#
#
# Clock: 17
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(15)', 'P2(40)']
#
#
# Clock: 18
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(14)', 'P2(39)', 'P3(32)']
#
#
# Clock: 19
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(13)', 'P2(38)', 'P3(31)']
#
#
# Clock: 20
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(12)', 'P2(37)', 'P3(30)']
#
#
# Clock: 21
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(11)', 'P2(36)', 'P3(29)', 'P4(34)']
#
#
# Clock: 22
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(10)', 'P2(35)', 'P3(28)', 'P4(33)']
#
#
# Clock: 23
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(9)', 'P2(34)', 'P3(27)', 'P4(32)']
#
#
# Clock: 24
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(8)', 'P2(33)', 'P3(26)', 'P4(31)']
#
#
# Clock: 25
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(7)', 'P2(32)', 'P3(25)', 'P4(30)']
#
#
# Clock: 26
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(6)', 'P2(31)', 'P3(24)', 'P4(29)']
#
#
# Clock: 27
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(5)', 'P2(30)', 'P3(23)', 'P4(28)']
#
#
# Clock: 28
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(4)', 'P2(29)', 'P3(22)', 'P4(27)']
#
#
# Clock: 29
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(3)', 'P2(28)', 'P3(21)', 'P4(26)']
#
#
# Clock: 30
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(2)', 'P2(27)', 'P3(20)', 'P4(25)']
#
#
# Clock: 31
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P1(1)', 'P2(26)', 'P3(19)', 'P4(24)']
#
#
# Clock: 32
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(25)', 'P3(18)', 'P4(23)']
#
#
# Clock: 33
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(24)', 'P3(17)', 'P4(22)']
#
#
# Clock: 34
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(23)', 'P3(16)', 'P4(21)']
#
#
# Clock: 35
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(22)', 'P3(15)', 'P4(20)']
#
#
# Clock: 36
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(21)', 'P3(14)', 'P4(19)']
#
#
# Clock: 37
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(20)', 'P3(13)', 'P4(18)', 'P5(23)']
#
#
# Clock: 38
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(19)', 'P3(12)', 'P4(17)', 'P5(22)']
#
#
# Clock: 39
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(18)', 'P3(11)', 'P4(16)', 'P5(21)']
#
#
# Clock: 40
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(17)', 'P3(10)', 'P4(15)', 'P5(20)']
#
#
# Clock: 41
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(16)', 'P3(9)', 'P4(14)', 'P5(19)']
#
#
# Clock: 42
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(15)', 'P3(8)', 'P4(13)', 'P5(18)']
#
#
# Clock: 43
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(14)', 'P3(7)', 'P4(12)', 'P5(17)']
#
#
# Clock: 44
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(13)', 'P3(6)', 'P4(11)', 'P5(16)']
#
#
# Clock: 45
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(12)', 'P3(5)', 'P4(10)', 'P5(15)']
#
#
# Clock: 46
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(11)', 'P3(4)', 'P4(9)', 'P5(14)']
#
#
# Clock: 47
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(10)', 'P3(3)', 'P4(8)', 'P5(13)']
#
#
# Clock: 48
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(9)', 'P3(2)', 'P4(7)', 'P5(12)', 'P6(21)']
#
#
# Clock: 49
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P2(8)', 'P3(1)', 'P4(6)', 'P5(11)', 'P6(20)']
#
#
# Clock: 50
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(7)', 'P4(5)', 'P5(10)', 'P6(19)']
#
#
# Clock: 51
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(6)', 'P4(4)', 'P5(9)', 'P6(18)']
#
#
# Clock: 52
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(5)', 'P4(3)', 'P5(8)', 'P6(17)']
#
#
# Clock: 53
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(4)', 'P4(2)', 'P5(7)', 'P6(16)']
#
#
# Clock: 54
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(3)', 'P4(1)', 'P5(6)', 'P6(15)']
#
#
# Clock: 55
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])']
# I/O Queue: ['P2(2)', 'P5(5)', 'P6(14)']
#
#
# Clock: 56
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])']
# I/O Queue: ['P2(1)', 'P5(4)', 'P6(13)']
#
#
# Clock: 57
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P5(3)', 'P6(12)']
#
#
# Clock: 58
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P5(2)', 'P6(11)']
#
#
# Clock: 59
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P5(1)', 'P6(10)']
#
#
# Clock: 60
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(9)']
#
#
# Clock: 61
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(8)']
#
#
# Clock: 62
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(7)', 'P7(45)']
#
#
# Clock: 63
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(6)', 'P7(44)']
#
#
# Clock: 64
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(5)', 'P7(43)']
#
#
# Clock: 65
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(4)', 'P7(42)']
#
#
# Clock: 66
# Running Process: P1 Burst Time: 3
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(3)', 'P7(41)', 'P8(13)']
#
#
# Clock: 67
# Running Process: P1 Burst Time: 3
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(2)', 'P7(40)', 'P8(12)']
#
#
# Clock: 68
# Running Process: P1 Burst Time: 3
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P6(1)', 'P7(39)', 'P8(11)']
#
#
# Clock: 69
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(38)', 'P8(10)', 'P1(30)']
#
#
# Clock: 70
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(37)', 'P8(9)', 'P1(29)']
#
#
# Clock: 71
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(36)', 'P8(8)', 'P1(28)']
#
#
# Clock: 72
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(35)', 'P8(7)', 'P1(27)']
#
#
# Clock: 73
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(34)', 'P8(6)', 'P1(26)']
#
#
# Clock: 74
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(33)', 'P8(5)', 'P1(25)']
#
#
# Clock: 75
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(32)', 'P8(4)', 'P1(24)']
#
#
# Clock: 76
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(31)', 'P8(3)', 'P1(23)']
#
#
# Clock: 77
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(30)', 'P8(2)', 'P1(22)']
#
#
# Clock: 78
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P7(29)', 'P8(1)', 'P1(21)']
#
#
# Clock: 79
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(28)', 'P1(20)']
#
#
# Clock: 80
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(27)', 'P1(19)']
#
#
# Clock: 81
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(26)', 'P1(18)', 'P3(40)']
#
#
# Clock: 82
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(25)', 'P1(17)', 'P3(39)']
#
#
# Clock: 83
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(24)', 'P1(16)', 'P3(38)']
#
#
# Clock: 84
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(23)', 'P1(15)', 'P3(37)']
#
#
# Clock: 85
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(22)', 'P1(14)', 'P3(36)', 'P4(40)']
#
#
# Clock: 86
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(21)', 'P1(13)', 'P3(35)', 'P4(39)']
#
#
# Clock: 87
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(20)', 'P1(12)', 'P3(34)', 'P4(38)']
#
#
# Clock: 88
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(19)', 'P1(11)', 'P3(33)', 'P4(37)']
#
#
# Clock: 89
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(18)', 'P1(10)', 'P3(32)', 'P4(36)']
#
#
# Clock: 90
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(17)', 'P1(9)', 'P3(31)', 'P4(35)', 'P2(43)']
#
#
# Clock: 91
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(16)', 'P1(8)', 'P3(30)', 'P4(34)', 'P2(42)']
#
#
# Clock: 92
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(15)', 'P1(7)', 'P3(29)', 'P4(33)', 'P2(41)']
#
#
# Clock: 93
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(14)', 'P1(6)', 'P3(28)', 'P4(32)', 'P2(40)']
#
#
# Clock: 94
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(13)', 'P1(5)', 'P3(27)', 'P4(31)', 'P2(39)']
#
#
# Clock: 95
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(12)', 'P1(4)', 'P3(26)', 'P4(30)', 'P2(38)']
#
#
# Clock: 96
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(11)', 'P1(3)', 'P3(25)', 'P4(29)', 'P2(37)']
#
#
# Clock: 97
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(10)', 'P1(2)', 'P3(24)', 'P4(28)', 'P2(36)']
#
#
# Clock: 98
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])']
# I/O Queue: ['P7(9)', 'P1(1)', 'P3(23)', 'P4(27)', 'P2(35)']
#
#
# Clock: 99
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(8)', 'P3(22)', 'P4(26)', 'P2(34)']
#
#
# Clock: 100
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(7)', 'P3(21)', 'P4(25)', 'P2(33)']
#
#
# Clock: 101
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(6)', 'P3(20)', 'P4(24)', 'P2(32)']
#
#
# Clock: 102
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(5)', 'P3(19)', 'P4(23)', 'P2(31)']
#
#
# Clock: 103
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(4)', 'P3(18)', 'P4(22)', 'P2(30)']
#
#
# Clock: 104
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(3)', 'P3(17)', 'P4(21)', 'P2(29)']
#
#
# Clock: 105
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(2)', 'P3(16)', 'P4(20)', 'P2(28)']
#
#
# Clock: 106
# Running Process: P5 Burst Time: 17
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])']
# I/O Queue: ['P7(1)', 'P3(15)', 'P4(19)', 'P2(27)']
#
#
# Clock: 107
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(14)', 'P4(18)', 'P2(26)', 'P5(20)']
#
#
# Clock: 108
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(13)', 'P4(17)', 'P2(25)', 'P5(19)']
#
#
# Clock: 109
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(12)', 'P4(16)', 'P2(24)', 'P5(18)']
#
#
# Clock: 110
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(11)', 'P4(15)', 'P2(23)', 'P5(17)']
#
#
# Clock: 111
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(10)', 'P4(14)', 'P2(22)', 'P5(16)', 'P6(7)']
#
#
# Clock: 112
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(9)', 'P4(13)', 'P2(21)', 'P5(15)', 'P6(6)']
#
#
# Clock: 113
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(8)', 'P4(12)', 'P2(20)', 'P5(14)', 'P6(5)']
#
#
# Clock: 114
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(7)', 'P4(11)', 'P2(19)', 'P5(13)', 'P6(4)']
#
#
# Clock: 115
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(6)', 'P4(10)', 'P2(18)', 'P5(12)', 'P6(3)']
#
#
# Clock: 116
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(5)', 'P4(9)', 'P2(17)', 'P5(11)', 'P6(2)', 'P8(32)']
#
#
# Clock: 117
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(4)', 'P4(8)', 'P2(16)', 'P5(10)', 'P6(1)', 'P8(31)']
#
#
# Clock: 118
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P3(3)', 'P4(7)', 'P2(15)', 'P5(9)', 'P8(30)']
#
#
# Clock: 119
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P3(2)', 'P4(6)', 'P2(14)', 'P5(8)', 'P8(29)']
#
#
# Clock: 120
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# I/O Queue: ['P3(1)', 'P4(5)', 'P2(13)', 'P5(7)', 'P8(28)']
#
#
# Clock: 121
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(4)', 'P2(12)', 'P5(6)', 'P8(27)', 'P1(42)']
#
#
# Clock: 122
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(3)', 'P2(11)', 'P5(5)', 'P8(26)', 'P1(41)']
#
#
# Clock: 123
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(2)', 'P2(10)', 'P5(4)', 'P8(25)', 'P1(40)']
#
#
# Clock: 124
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(1)', 'P2(9)', 'P5(3)', 'P8(24)', 'P1(39)']
#
#
# Clock: 125
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])']
# I/O Queue: ['P2(8)', 'P5(2)', 'P8(23)', 'P1(38)']
#
#
# Clock: 126
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])']
# I/O Queue: ['P2(7)', 'P5(1)', 'P8(22)', 'P1(37)']
#
#
# Clock: 127
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(6)', 'P8(21)', 'P1(36)']
#
#
# Clock: 128
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(5)', 'P8(20)', 'P1(35)']
#
#
# Clock: 129
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(4)', 'P8(19)', 'P1(34)']
#
#
# Clock: 130
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(3)', 'P8(18)', 'P1(33)']
#
#
# Clock: 131
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(2)', 'P8(17)', 'P1(32)']
#
#
# Clock: 132
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(1)', 'P8(16)', 'P1(31)']
#
#
# Clock: 133
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(15)', 'P1(30)']
#
#
# Clock: 134
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(14)', 'P1(29)']
#
#
# Clock: 135
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(13)', 'P1(28)']
#
#
# Clock: 136
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(12)', 'P1(27)']
#
#
# Clock: 137
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(11)', 'P1(26)']
#
#
# Clock: 138
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(10)', 'P1(25)', 'P7(40)']
#
#
# Clock: 139
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(9)', 'P1(24)', 'P7(39)']
#
#
# Clock: 140
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(8)', 'P1(23)', 'P7(38)']
#
#
# Clock: 141
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(7)', 'P1(22)', 'P7(37)']
#
#
# Clock: 142
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(6)', 'P1(21)', 'P7(36)']
#
#
# Clock: 143
# Running Process: P3 Burst Time: 18
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(5)', 'P1(20)', 'P7(35)', 'P6(9)']
#
#
# Clock: 144
# Running Process: P3 Burst Time: 18
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(4)', 'P1(19)', 'P7(34)', 'P6(8)']
#
#
# Clock: 145
# Running Process: P3 Burst Time: 18
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(3)', 'P1(18)', 'P7(33)', 'P6(7)']
#
#
# Clock: 146
# Running Process: P3 Burst Time: 18
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(2)', 'P1(17)', 'P7(32)', 'P6(6)']
#
#
# Clock: 147
# Running Process: P3 Burst Time: 18
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# I/O Queue: ['P8(1)', 'P1(16)', 'P7(31)', 'P6(5)']
#
#
# Clock: 148
# Running Process: P3 Burst Time: 18
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P5([5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P8([6, 51, 14, 73, 16, 87, 6])']
# ...
# Ready Queue: ['P8([6])', 'P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(12)', 'P3(19)', 'P4(81)']
#
#
# Clock: 483
# Running Process: P5 Burst Time: 6
# Ready Queue: ['P8([6])', 'P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(11)', 'P3(18)', 'P4(80)']
#
#
# Clock: 484
# Running Process: P5 Burst Time: 6
# Ready Queue: ['P8([6])', 'P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(10)', 'P3(17)', 'P4(79)']
#
#
# Clock: 485
# Running Process: P5 Burst Time: 6
# Ready Queue: ['P8([6])', 'P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(9)', 'P3(16)', 'P4(78)']
#
#
# Clock: 486
# Running Process: P5 Burst Time: 6
# Ready Queue: ['P8([6])', 'P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(8)', 'P3(15)', 'P4(77)']
#
#
# Clock: 487
# Running Process: P5 Burst Time: 6
# Ready Queue: ['P8([6])', 'P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(7)', 'P3(14)', 'P4(76)']
#
#
# Clock: 488
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(6)', 'P3(13)', 'P4(75)', 'P5(12)']
#
#
# Clock: 489
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(5)', 'P3(12)', 'P4(74)', 'P5(11)']
#
#
# Clock: 490
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(4)', 'P3(11)', 'P4(73)', 'P5(10)']
#
#
# Clock: 491
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(3)', 'P3(10)', 'P4(72)', 'P5(9)']
#
#
# Clock: 492
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(2)', 'P3(9)', 'P4(71)', 'P5(8)']
#
#
# Clock: 493
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P2([9, 31, 7, 43, 8])']
# I/O Queue: ['P7(1)', 'P3(8)', 'P4(70)', 'P5(7)']
#
#
# Process P8 has completed its total execution.
# Clock: 494
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])']
# I/O Queue: ['P3(7)', 'P4(69)', 'P5(6)']
#
#
# Clock: 495
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])']
# I/O Queue: ['P3(6)', 'P4(68)', 'P5(5)']
#
#
# Clock: 496
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])']
# I/O Queue: ['P3(5)', 'P4(67)', 'P5(4)']
#
#
# Clock: 497
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])']
# I/O Queue: ['P3(4)', 'P4(66)', 'P5(3)']
#
#
# Clock: 498
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])']
# I/O Queue: ['P3(3)', 'P4(65)', 'P5(2)']
#
#
# Clock: 499
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])']
# I/O Queue: ['P3(2)', 'P4(64)', 'P5(1)']
#
#
# Clock: 500
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])', 'P5([3, 11, 4])']
# I/O Queue: ['P3(1)', 'P4(63)']
#
#
# Clock: 501
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])', 'P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(62)']
#
#
# Clock: 502
# Running Process: P2 Burst Time: 9
# Ready Queue: ['P7([10])', 'P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(61)']
#
#
# Clock: 503
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(60)', 'P2(30)']
#
#
# Clock: 504
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(59)', 'P2(29)']
#
#
# Clock: 505
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(58)', 'P2(28)']
#
#
# Clock: 506
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(57)', 'P2(27)']
#
#
# Clock: 507
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(56)', 'P2(26)']
#
#
# Clock: 508
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(55)', 'P2(25)']
#
#
# Clock: 509
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(54)', 'P2(24)']
#
#
# Clock: 510
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(53)', 'P2(23)']
#
#
# Clock: 511
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(52)', 'P2(22)']
#
#
# Clock: 512
# Running Process: P7 Burst Time: 10
# Ready Queue: ['P5([3, 11, 4])', 'P3([5, 31, 6])']
# I/O Queue: ['P4(51)', 'P2(21)']
#
#
# Process P7 has completed its total execution.
# Clock: 513
# Running Process: P5 Burst Time: 3
# Ready Queue: ['P3([5, 31, 6])']
# I/O Queue: ['P4(50)', 'P2(20)']
#
#
# Clock: 514
# Running Process: P5 Burst Time: 3
# Ready Queue: ['P3([5, 31, 6])']
# I/O Queue: ['P4(49)', 'P2(19)']
#
#
# Clock: 515
# Running Process: P5 Burst Time: 3
# Ready Queue: ['P3([5, 31, 6])']
# I/O Queue: ['P4(48)', 'P2(18)']
#
#
# Clock: 516
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P4(47)', 'P2(17)', 'P5(10)']
#
#
# Clock: 517
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P4(46)', 'P2(16)', 'P5(9)']
#
#
# Clock: 518
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P4(45)', 'P2(15)', 'P5(8)']
#
#
# Clock: 519
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P4(44)', 'P2(14)', 'P5(7)']
#
#
# Clock: 520
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P4(43)', 'P2(13)', 'P5(6)']
#
#
# Clock: 521
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(42)', 'P2(12)', 'P5(5)', 'P3(30)']
#
#
# Clock: 522
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(41)', 'P2(11)', 'P5(4)', 'P3(29)']
#
#
# Clock: 523
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(40)', 'P2(10)', 'P5(3)', 'P3(28)']
#
#
# Clock: 524
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(39)', 'P2(9)', 'P5(2)', 'P3(27)']
#
#
# Clock: 525
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(38)', 'P2(8)', 'P5(1)', 'P3(26)']
#
#
# Clock: 526
# Running Process: None
# Ready Queue: ['P5([4])']
# I/O Queue: ['P4(37)', 'P2(7)', 'P3(25)']
#
#
# Clock: 527
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P4(36)', 'P2(6)', 'P3(24)']
#
#
# Clock: 528
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P4(35)', 'P2(5)', 'P3(23)']
#
#
# Clock: 529
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P4(34)', 'P2(4)', 'P3(22)']
#
#
# Clock: 530
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P4(33)', 'P2(3)', 'P3(21)']
#
#
# Process P5 has completed its total execution.
# Clock: 531
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(32)', 'P2(2)', 'P3(20)']
#
#
# Clock: 532
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(31)', 'P2(1)', 'P3(19)']
#
#
# Clock: 533
# Running Process: None
# Ready Queue: ['P2([7, 43, 8])']
# I/O Queue: ['P4(30)', 'P3(18)']
#
#
# Clock: 534
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(29)', 'P3(17)']
#
#
# Clock: 535
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(28)', 'P3(16)']
#
#
# Clock: 536
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(27)', 'P3(15)']
#
#
# Clock: 537
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(26)', 'P3(14)']
#
#
# Clock: 538
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(25)', 'P3(13)']
#
#
# Clock: 539
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(24)', 'P3(12)']
#
#
# Clock: 540
# Running Process: P2 Burst Time: 7
# Ready Queue: []
# I/O Queue: ['P4(23)', 'P3(11)']
#
#
# Clock: 541
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(22)', 'P3(10)', 'P2(42)']
#
#
# Clock: 542
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(21)', 'P3(9)', 'P2(41)']
#
#
# Clock: 543
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(20)', 'P3(8)', 'P2(40)']
#
#
# Clock: 544
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(19)', 'P3(7)', 'P2(39)']
#
#
# Clock: 545
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(18)', 'P3(6)', 'P2(38)']
#
#
# Clock: 546
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(17)', 'P3(5)', 'P2(37)']
#
#
# Clock: 547
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(16)', 'P3(4)', 'P2(36)']
#
#
# Clock: 548
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(15)', 'P3(3)', 'P2(35)']
#
#
# Clock: 549
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(14)', 'P3(2)', 'P2(34)']
#
#
# Clock: 550
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(13)', 'P3(1)', 'P2(33)']
#
#
# Clock: 551
# Running Process: None
# Ready Queue: ['P3([6])']
# I/O Queue: ['P4(12)', 'P2(32)']
#
#
# Clock: 552
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(11)', 'P2(31)']
#
#
# Clock: 553
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(10)', 'P2(30)']
#
#
# Clock: 554
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(9)', 'P2(29)']
#
#
# Clock: 555
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(8)', 'P2(28)']
#
#
# Clock: 556
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(7)', 'P2(27)']
#
#
# Clock: 557
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(6)', 'P2(26)']
#
#
# Process P3 has completed its total execution.
# Clock: 558
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(5)', 'P2(25)']
#
#
# Clock: 559
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(4)', 'P2(24)']
#
#
# Clock: 560
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(3)', 'P2(23)']
#
#
# Clock: 561
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(2)', 'P2(22)']
#
#
# Clock: 562
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(1)', 'P2(21)']
#
#
# Clock: 563
# Running Process: None
# Ready Queue: ['P4([5, 77, 3])']
# I/O Queue: ['P2(20)']
#
#
# Clock: 564
# Running Process: P4 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P2(19)']
#
#
# Clock: 565
# Running Process: P4 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P2(18)']
#
#
# Clock: 566
# Running Process: P4 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P2(17)']
#
#
# Clock: 567
# Running Process: P4 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P2(16)']
#
#
# Clock: 568
# Running Process: P4 Burst Time: 5
# Ready Queue: []
# I/O Queue: ['P2(15)']
#
#
# Clock: 569
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(14)', 'P4(76)']
#
#
# Clock: 570
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(13)', 'P4(75)']
#
#
# Clock: 571
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(12)', 'P4(74)']
#
#
# Clock: 572
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(11)', 'P4(73)']
#
#
# Clock: 573
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(10)', 'P4(72)']
#
#
# Clock: 574
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(9)', 'P4(71)']
#
#
# Clock: 575
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(8)', 'P4(70)']
#
#
# Clock: 576
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(7)', 'P4(69)']
#
#
# Clock: 577
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(6)', 'P4(68)']
#
#
# Clock: 578
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(5)', 'P4(67)']
#
#
# Clock: 579
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(4)', 'P4(66)']
#
#
# Clock: 580
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(3)', 'P4(65)']
#
#
# Clock: 581
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(2)', 'P4(64)']
#
#
# Clock: 582
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P2(1)', 'P4(63)']
#
#
# Clock: 583
# Running Process: None
# Ready Queue: ['P2([8])']
# I/O Queue: ['P4(62)']
#
#
# Clock: 584
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(61)']
#
#
# Clock: 585
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(60)']
#
#
# Clock: 586
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(59)']
#
#
# Clock: 587
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(58)']
#
#
# Clock: 588
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(57)']
#
#
# Clock: 589
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(56)']
#
#
# Clock: 590
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(55)']
#
#
# Clock: 591
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(54)']
#
#
# Process P2 has completed its total execution.
# Clock: 592
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(53)']
#
#
# Clock: 593
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(52)']
#
#
# Clock: 594
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(51)']
#
#
# Clock: 595
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(50)']
#
#
# Clock: 596
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(49)']
#
#
# Clock: 597
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(48)']
#
#
# Clock: 598
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(47)']
#
#
# Clock: 599
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(46)']
#
#
# Clock: 600
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(45)']
#
#
# Clock: 601
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(44)']
#
#
# Clock: 602
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(43)']
#
#
# Clock: 603
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(42)']
#
#
# Clock: 604
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(41)']
#
#
# Clock: 605
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(40)']
#
#
# Clock: 606
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(39)']
#
#
# Clock: 607
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(38)']
#
#
# Clock: 608
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(37)']
#
#
# Clock: 609
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(36)']
#
#
# Clock: 610
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(35)']
#
#
# Clock: 611
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(34)']
#
#
# Clock: 612
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(33)']
#
#
# Clock: 613
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(32)']
#
#
# Clock: 614
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(31)']
#
#
# Clock: 615
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(30)']
#
#
# Clock: 616
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(29)']
#
#
# Clock: 617
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(28)']
#
#
# Clock: 618
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(27)']
#
#
# Clock: 619
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(26)']
#
#
# Clock: 620
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(25)']
#
#
# Clock: 621
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(24)']
#
#
# Clock: 622
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(23)']
#
#
# Clock: 623
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(22)']
#
#
# Clock: 624
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(21)']
#
#
# Clock: 625
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(20)']
#
#
# Clock: 626
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(19)']
#
#
# Clock: 627
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(18)']
#
#
# Clock: 628
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(17)']
#
#
# Clock: 629
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(16)']
#
#
# Clock: 630
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(15)']
#
#
# Clock: 631
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(14)']
#
#
# Clock: 632
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(13)']
#
#
# Clock: 633
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(12)']
#
#
# Clock: 634
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(11)']
#
#
# Clock: 635
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(10)']
#
#
# Clock: 636
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(9)']
#
#
# Clock: 637
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(8)']
#
#
# Clock: 638
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(7)']
#
#
# Clock: 639
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(6)']
#
#
# Clock: 640
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(5)']
#
#
# Clock: 641
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(4)']
#
#
# Clock: 642
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(3)']
#
#
# Clock: 643
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(2)']
#
#
# Clock: 644
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(1)']
#
#
# Clock: 645
# Running Process: None
# Ready Queue: ['P4([3])']
# I/O Queue: []
#
#
# Clock: 646
# Running Process: P4 Burst Time: 3
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 647
# Running Process: P4 Burst Time: 3
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 648
# Running Process: P4 Burst Time: 3
# Ready Queue: []
# I/O Queue: []
#
#
# Process P4 has completed its total execution.
# Process	Waiting Time	Turnaround Time	Response Time
# P1	170		395		0
# P2	164		591		5
# P3	165		557		9
# P4	164		648		17
# P5	221		530		20
# P6	230		445		36
# P7	184		512		47
# P8	184		493		61
#
# Average Waiting Time: 185.25
# Average Turnaround Time: 521.375
# Average Response Time: 24.375
# CPU Utilization: 0.8520801232665639%
# Total Run Time: 649

# %% [markdown]
# SJF (non-preemptive)

# %%
"""
The process class stores each processes CPU and I/O bursts, process id, total burst time,
wait time, turnaround time, and response time.
"""
class Process:

    def __init__(self, pid, bursts):
        self.pid = pid
        self.bursts = bursts
        self.total_burst_time = sum(bursts) #Total burst time to calculate wait time
        self.wait_time = 0
        self.turnaround_time = 0
        self.response_time = 1 #Set to 1 initially

P1 = Process(1, [5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])
P2 = Process(2, [4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])
P3 = Process(3, [8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])
P4 = Process(4, [3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])
P5 = Process(5, [16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])
P6 = Process(6, [11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])
P7 = Process(7, [14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])
P8 = Process(8, [4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])

processes = [P1, P2, P3, P4, P5, P6, P7, P8]

#Total for cpu bursts to later calculate cpu utilization
burst_time = 553

# %%
#Funtion to sort processes based on shortest burst times
def insert_sorted(readyQueue, process):
    i = 0
    while i < len(readyQueue) and readyQueue[i].bursts[0] <= process.bursts[0]:
        i += 1
    #Adds the sorted process to the ready queu
    readyQueue.insert(i, process)

def sjf(processes):
    clock = 0
    ready_queue = []
    io_queue = []
    running_process = 0 #0 means no process is running
    running_time = 0

    def printExecution():
      #Prints the current run time, the current running process, and the ready / IO queues
      print(f"Clock: {clock}")

      if running_process == 0:
          print("Running Process: None")
      else:
          print(f"Running Process: P{running_process.pid} Burst Time: {running_process.bursts[0]}")

      print("Ready Queue:", [f"P{p.pid}({p.bursts})" for p in ready_queue])
      print("I/O Queue:", [f"P{p[0].pid}({p[1]})" for p in io_queue])
      print("\n")


    #Sorts the processes and adds them to  the ready queue
    for p in processes:
        insert_sorted(ready_queue, p)

    #checks if there are processes in ready queue, io queue, or if a process is currently running
    while len(ready_queue) > 0 or len(io_queue) > 0 or running_process != 0:
        printExecution()
        #If a process is running, running time gets incremented
        if running_process:
            running_time += 1
            #If the run time equals the burst value it removes the process
            if running_time == running_process.bursts[0]:
                running_process.bursts.pop(0)
                #if a process finishes its cpu burst and still has bursts to run, it gets sent to the io queue
                if running_process.bursts:
                    #adds the io burst time
                    io_time = running_process.bursts.pop(0)
                    #adds the process to the io queue
                    io_queue.append((running_process, io_time))
                #else the process has finished
                else:
                    running_process.turnaround_time = clock
                    print(f"Process P{running_process.pid} has completed its total execution.")

                #resets the run time and running process
                running_process = 0
                running_time = 0

        #Checks if there are not processes currently running
        #Also checks if there are processes in the ready queue
        if running_process == 0 and len(ready_queue) > 0:
          #Sets the next process in the queue to run its cpu burst
          running_process = ready_queue.pop(0)

          if running_process.response_time == 1:
            #All processes are initialized with a response time of 1
            #This then sets the response time to the clock value if its their first time running
              running_process.response_time = clock

        #creates a new io queue
        new_io_queue = []
        #checks if a process still has time left for its io burst
        for p, time_left in io_queue:
            time_left -= 1
          #once a process has finished it is sorted by sjf and added to ready queue
            if time_left == 0:
                insert_sorted(ready_queue, p)
          #else the remaining processes are added to a new queue to finish their io bursts
            else:
                new_io_queue.append((p, time_left))
        #remakes the io queue and increments the clock by 1
        io_queue = new_io_queue
        clock += 1
    #Calculates wait time for all processes
    for p in processes:
        p.wait_time = p.turnaround_time - p.total_burst_time
    #returns each process instance and the final run time
    return processes, clock


def generateStats(processData, clock):
  #Prints all the final stats
    avg_wait_time = sum(p.wait_time for p in processes) / 8
    avg_turnaround_time = sum(p.turnaround_time for p in processes) / 8
    avg_response_time = sum(p.response_time for p in processes) / 8
    cpu_utilization = (burst_time / clock)

    print("Process\tWaiting Time\tTurnaround Time\tResponse Time")
    for p in processData:
        print(f"P{p.pid}\t{p.wait_time}\t\t{p.turnaround_time}\t\t{p.response_time}")
    print(f"\nAverage Waiting Time: {avg_wait_time}")
    print(f"Average Turnaround Time: {avg_turnaround_time}")
    print(f"Average Response Time: {avg_response_time}")
    print(f"CPU Utilization: {cpu_utilization}%")
    print(f"Total Run Time: {clock}")

if __name__ == "__main__":
    processData, clock = sjf(processes)
    generateStats(processData, clock)
# Out:
# Clock: 0
# Running Process: None
# Ready Queue: ['P4([3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: []
#
#
# Clock: 1
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: []
#
#
# Clock: 2
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: []
#
#
# Clock: 3
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P2([4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: []
#
#
# Clock: 4
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(34)']
#
#
# Clock: 5
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(33)']
#
#
# Clock: 6
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(32)']
#
#
# Clock: 7
# Running Process: P2 Burst Time: 4
# Ready Queue: ['P8([4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(31)']
#
#
# Clock: 8
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(30)', 'P2(47)']
#
#
# Clock: 9
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(29)', 'P2(46)']
#
#
# Clock: 10
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(28)', 'P2(45)']
#
#
# Clock: 11
# Running Process: P8 Burst Time: 4
# Ready Queue: ['P1([5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(27)', 'P2(44)']
#
#
# Clock: 12
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(26)', 'P2(43)', 'P8(13)']
#
#
# Clock: 13
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(25)', 'P2(42)', 'P8(12)']
#
#
# Clock: 14
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(24)', 'P2(41)', 'P8(11)']
#
#
# Clock: 15
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(23)', 'P2(40)', 'P8(10)']
#
#
# Clock: 16
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P3([8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(22)', 'P2(39)', 'P8(9)']
#
#
# Clock: 17
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(21)', 'P2(38)', 'P8(8)', 'P1(26)']
#
#
# Clock: 18
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(20)', 'P2(37)', 'P8(7)', 'P1(25)']
#
#
# Clock: 19
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(19)', 'P2(36)', 'P8(6)', 'P1(24)']
#
#
# Clock: 20
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(18)', 'P2(35)', 'P8(5)', 'P1(23)']
#
#
# Clock: 21
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(17)', 'P2(34)', 'P8(4)', 'P1(22)']
#
#
# Clock: 22
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(16)', 'P2(33)', 'P8(3)', 'P1(21)']
#
#
# Clock: 23
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(15)', 'P2(32)', 'P8(2)', 'P1(20)']
#
#
# Clock: 24
# Running Process: P3 Burst Time: 8
# Ready Queue: ['P6([11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(14)', 'P2(31)', 'P8(1)', 'P1(19)']
#
#
# Clock: 25
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(13)', 'P2(30)', 'P1(18)', 'P3(32)']
#
#
# Clock: 26
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(12)', 'P2(29)', 'P1(17)', 'P3(31)']
#
#
# Clock: 27
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(11)', 'P2(28)', 'P1(16)', 'P3(30)']
#
#
# Clock: 28
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(10)', 'P2(27)', 'P1(15)', 'P3(29)']
#
#
# Clock: 29
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(9)', 'P2(26)', 'P1(14)', 'P3(28)']
#
#
# Clock: 30
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(8)', 'P2(25)', 'P1(13)', 'P3(27)']
#
#
# Clock: 31
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(7)', 'P2(24)', 'P1(12)', 'P3(26)']
#
#
# Clock: 32
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(6)', 'P2(23)', 'P1(11)', 'P3(25)']
#
#
# Clock: 33
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(5)', 'P2(22)', 'P1(10)', 'P3(24)']
#
#
# Clock: 34
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(4)', 'P2(21)', 'P1(9)', 'P3(23)']
#
#
# Clock: 35
# Running Process: P6 Burst Time: 11
# Ready Queue: ['P8([5, 33, 6, 51, 14, 73, 16, 87, 6])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(3)', 'P2(20)', 'P1(8)', 'P3(22)']
#
#
# Clock: 36
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(2)', 'P2(19)', 'P1(7)', 'P3(21)', 'P6(21)']
#
#
# Clock: 37
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(1)', 'P2(18)', 'P1(6)', 'P3(20)', 'P6(20)']
#
#
# Clock: 38
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(17)', 'P1(5)', 'P3(19)', 'P6(19)']
#
#
# Clock: 39
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(16)', 'P1(4)', 'P3(18)', 'P6(18)']
#
#
# Clock: 40
# Running Process: P8 Burst Time: 5
# Ready Queue: ['P4([4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(15)', 'P1(3)', 'P3(17)', 'P6(17)']
#
#
# Clock: 41
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(14)', 'P1(2)', 'P3(16)', 'P6(16)', 'P8(32)']
#
#
# Clock: 42
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(13)', 'P1(1)', 'P3(15)', 'P6(15)', 'P8(31)']
#
#
# Clock: 43
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(12)', 'P3(14)', 'P6(14)', 'P8(30)']
#
#
# Clock: 44
# Running Process: P4 Burst Time: 4
# Ready Queue: ['P1([3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(11)', 'P3(13)', 'P6(13)', 'P8(29)']
#
#
# Clock: 45
# Running Process: P1 Burst Time: 3
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(10)', 'P3(12)', 'P6(12)', 'P8(28)', 'P4(40)']
#
#
# Clock: 46
# Running Process: P1 Burst Time: 3
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(9)', 'P3(11)', 'P6(11)', 'P8(27)', 'P4(39)']
#
#
# Clock: 47
# Running Process: P1 Burst Time: 3
# Ready Queue: ['P7([14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(8)', 'P3(10)', 'P6(10)', 'P8(26)', 'P4(38)']
#
#
# Clock: 48
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(7)', 'P3(9)', 'P6(9)', 'P8(25)', 'P4(37)', 'P1(30)']
#
#
# Clock: 49
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(6)', 'P3(8)', 'P6(8)', 'P8(24)', 'P4(36)', 'P1(29)']
#
#
# Clock: 50
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(5)', 'P3(7)', 'P6(7)', 'P8(23)', 'P4(35)', 'P1(28)']
#
#
# Clock: 51
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(4)', 'P3(6)', 'P6(6)', 'P8(22)', 'P4(34)', 'P1(27)']
#
#
# Clock: 52
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(3)', 'P3(5)', 'P6(5)', 'P8(21)', 'P4(33)', 'P1(26)']
#
#
# Clock: 53
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(2)', 'P3(4)', 'P6(4)', 'P8(20)', 'P4(32)', 'P1(25)']
#
#
# Clock: 54
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(1)', 'P3(3)', 'P6(3)', 'P8(19)', 'P4(31)', 'P1(24)']
#
#
# Clock: 55
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(2)', 'P6(2)', 'P8(18)', 'P4(30)', 'P1(23)']
#
#
# Clock: 56
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(1)', 'P6(1)', 'P8(17)', 'P4(29)', 'P1(22)']
#
#
# Clock: 57
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(16)', 'P4(28)', 'P1(21)']
#
#
# Clock: 58
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(15)', 'P4(27)', 'P1(20)']
#
#
# Clock: 59
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(14)', 'P4(26)', 'P1(19)']
#
#
# Clock: 60
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(13)', 'P4(25)', 'P1(18)']
#
#
# Clock: 61
# Running Process: P7 Burst Time: 14
# Ready Queue: ['P6([4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(12)', 'P4(24)', 'P1(17)']
#
#
# Clock: 62
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(11)', 'P4(23)', 'P1(16)', 'P7(45)']
#
#
# Clock: 63
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(10)', 'P4(22)', 'P1(15)', 'P7(44)']
#
#
# Clock: 64
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(9)', 'P4(21)', 'P1(14)', 'P7(43)']
#
#
# Clock: 65
# Running Process: P6 Burst Time: 4
# Ready Queue: ['P2([5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(8)', 'P4(20)', 'P1(13)', 'P7(42)']
#
#
# Clock: 66
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(7)', 'P4(19)', 'P1(12)', 'P7(41)', 'P6(7)']
#
#
# Clock: 67
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(6)', 'P4(18)', 'P1(11)', 'P7(40)', 'P6(6)']
#
#
# Clock: 68
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(5)', 'P4(17)', 'P1(10)', 'P7(39)', 'P6(5)']
#
#
# Clock: 69
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(4)', 'P4(16)', 'P1(9)', 'P7(38)', 'P6(4)']
#
#
# Clock: 70
# Running Process: P2 Burst Time: 5
# Ready Queue: ['P3([12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(3)', 'P4(15)', 'P1(8)', 'P7(37)', 'P6(3)']
#
#
# Clock: 71
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(2)', 'P4(14)', 'P1(7)', 'P7(36)', 'P6(2)', 'P2(43)']
#
#
# Clock: 72
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(1)', 'P4(13)', 'P1(6)', 'P7(35)', 'P6(1)', 'P2(42)']
#
#
# Clock: 73
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(12)', 'P1(5)', 'P7(34)', 'P2(41)']
#
#
# Clock: 74
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(11)', 'P1(4)', 'P7(33)', 'P2(40)']
#
#
# Clock: 75
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(10)', 'P1(3)', 'P7(32)', 'P2(39)']
#
#
# Clock: 76
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(9)', 'P1(2)', 'P7(31)', 'P2(38)']
#
#
# Clock: 77
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(8)', 'P1(1)', 'P7(30)', 'P2(37)']
#
#
# Clock: 78
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(7)', 'P7(29)', 'P2(36)']
#
#
# Clock: 79
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(6)', 'P7(28)', 'P2(35)']
#
#
# Clock: 80
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(5)', 'P7(27)', 'P2(34)']
#
#
# Clock: 81
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(4)', 'P7(26)', 'P2(33)']
#
#
# Clock: 82
# Running Process: P3 Burst Time: 12
# Ready Queue: ['P6([5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(3)', 'P7(25)', 'P2(32)']
#
#
# Clock: 83
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(2)', 'P7(24)', 'P2(31)', 'P3(40)']
#
#
# Clock: 84
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(1)', 'P7(23)', 'P2(30)', 'P3(39)']
#
#
# Clock: 85
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(22)', 'P2(29)', 'P3(38)']
#
#
# Clock: 86
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(21)', 'P2(28)', 'P3(37)']
#
#
# Clock: 87
# Running Process: P6 Burst Time: 5
# Ready Queue: ['P1([5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(20)', 'P2(27)', 'P3(36)']
#
#
# Clock: 88
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(19)', 'P2(26)', 'P3(35)', 'P6(9)']
#
#
# Clock: 89
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(18)', 'P2(25)', 'P3(34)', 'P6(8)']
#
#
# Clock: 90
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(17)', 'P2(24)', 'P3(33)', 'P6(7)']
#
#
# Clock: 91
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(16)', 'P2(23)', 'P3(32)', 'P6(6)']
#
#
# Clock: 92
# Running Process: P1 Burst Time: 5
# Ready Queue: ['P4([5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(15)', 'P2(22)', 'P3(31)', 'P6(5)']
#
#
# Clock: 93
# Running Process: P4 Burst Time: 5
# Ready Queue: ['P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(14)', 'P2(21)', 'P3(30)', 'P6(4)', 'P1(42)']
#
#
# Clock: 94
# Running Process: P4 Burst Time: 5
# Ready Queue: ['P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(13)', 'P2(20)', 'P3(29)', 'P6(3)', 'P1(41)']
#
#
# Clock: 95
# Running Process: P4 Burst Time: 5
# Ready Queue: ['P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(12)', 'P2(19)', 'P3(28)', 'P6(2)', 'P1(40)']
#
#
# Clock: 96
# Running Process: P4 Burst Time: 5
# Ready Queue: ['P8([6, 51, 14, 73, 16, 87, 6])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(11)', 'P2(18)', 'P3(27)', 'P6(1)', 'P1(39)']
#
#
# Clock: 97
# Running Process: P4 Burst Time: 5
# Ready Queue: ['P8([6, 51, 14, 73, 16, 87, 6])', 'P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(10)', 'P2(17)', 'P3(26)', 'P1(38)']
#
#
# Clock: 98
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(9)', 'P2(16)', 'P3(25)', 'P1(37)', 'P4(44)']
#
#
# Clock: 99
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(8)', 'P2(15)', 'P3(24)', 'P1(36)', 'P4(43)']
#
#
# Clock: 100
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(7)', 'P2(14)', 'P3(23)', 'P1(35)', 'P4(42)']
#
#
# Clock: 101
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(6)', 'P2(13)', 'P3(22)', 'P1(34)', 'P4(41)']
#
#
# Clock: 102
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(5)', 'P2(12)', 'P3(21)', 'P1(33)', 'P4(40)']
#
#
# Clock: 103
# Running Process: P8 Burst Time: 6
# Ready Queue: ['P6([6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(4)', 'P2(11)', 'P3(20)', 'P1(32)', 'P4(39)']
#
#
# Clock: 104
# Running Process: P6 Burst Time: 6
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(3)', 'P2(10)', 'P3(19)', 'P1(31)', 'P4(38)', 'P8(50)']
#
#
# Clock: 105
# Running Process: P6 Burst Time: 6
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(2)', 'P2(9)', 'P3(18)', 'P1(30)', 'P4(37)', 'P8(49)']
#
#
# Clock: 106
# Running Process: P6 Burst Time: 6
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(1)', 'P2(8)', 'P3(17)', 'P1(29)', 'P4(36)', 'P8(48)']
#
#
# Clock: 107
# Running Process: P6 Burst Time: 6
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(7)', 'P3(16)', 'P1(28)', 'P4(35)', 'P8(47)']
#
#
# Clock: 108
# Running Process: P6 Burst Time: 6
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(6)', 'P3(15)', 'P1(27)', 'P4(34)', 'P8(46)']
#
#
# Clock: 109
# Running Process: P6 Burst Time: 6
# Ready Queue: ['P5([16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(5)', 'P3(14)', 'P1(26)', 'P4(33)', 'P8(45)']
#
#
# Clock: 110
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(4)', 'P3(13)', 'P1(25)', 'P4(32)', 'P8(44)', 'P6(11)']
#
#
# Clock: 111
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(3)', 'P3(12)', 'P1(24)', 'P4(31)', 'P8(43)', 'P6(10)']
#
#
# Clock: 112
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(2)', 'P3(11)', 'P1(23)', 'P4(30)', 'P8(42)', 'P6(9)']
#
#
# Clock: 113
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P2(1)', 'P3(10)', 'P1(22)', 'P4(29)', 'P8(41)', 'P6(8)']
#
#
# Clock: 114
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(9)', 'P1(21)', 'P4(28)', 'P8(40)', 'P6(7)']
#
#
# Clock: 115
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(8)', 'P1(20)', 'P4(27)', 'P8(39)', 'P6(6)']
#
#
# Clock: 116
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(7)', 'P1(19)', 'P4(26)', 'P8(38)', 'P6(5)']
#
#
# Clock: 117
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(6)', 'P1(18)', 'P4(25)', 'P8(37)', 'P6(4)']
#
#
# Clock: 118
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(5)', 'P1(17)', 'P4(24)', 'P8(36)', 'P6(3)']
#
#
# Clock: 119
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(4)', 'P1(16)', 'P4(23)', 'P8(35)', 'P6(2)']
#
#
# Clock: 120
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(3)', 'P1(15)', 'P4(22)', 'P8(34)', 'P6(1)']
#
#
# Clock: 121
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(2)', 'P1(14)', 'P4(21)', 'P8(33)']
#
#
# Clock: 122
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# I/O Queue: ['P3(1)', 'P1(13)', 'P4(20)', 'P8(32)']
#
#
# Clock: 123
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(12)', 'P4(19)', 'P8(31)']
#
#
# Clock: 124
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(11)', 'P4(18)', 'P8(30)']
#
#
# Clock: 125
# Running Process: P5 Burst Time: 16
# Ready Queue: ['P2([7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(10)', 'P4(17)', 'P8(29)']
#
#
# Clock: 126
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(9)', 'P4(16)', 'P8(28)', 'P5(23)']
#
#
# Clock: 127
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(8)', 'P4(15)', 'P8(27)', 'P5(22)']
#
#
# Clock: 128
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(7)', 'P4(14)', 'P8(26)', 'P5(21)']
#
#
# Clock: 129
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(6)', 'P4(13)', 'P8(25)', 'P5(20)']
#
#
# Clock: 130
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(5)', 'P4(12)', 'P8(24)', 'P5(19)']
#
#
# Clock: 131
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(4)', 'P4(11)', 'P8(23)', 'P5(18)']
#
#
# Clock: 132
# Running Process: P2 Burst Time: 7
# Ready Queue: ['P6([7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(3)', 'P4(10)', 'P8(22)', 'P5(17)']
#
#
# Clock: 133
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(2)', 'P4(9)', 'P8(21)', 'P5(16)', 'P2(41)']
#
#
# Clock: 134
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P1(1)', 'P4(8)', 'P8(20)', 'P5(15)', 'P2(40)']
#
#
# Clock: 135
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P1([4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(7)', 'P8(19)', 'P5(14)', 'P2(39)']
#
#
# Clock: 136
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P1([4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(6)', 'P8(18)', 'P5(13)', 'P2(38)']
#
#
# Clock: 137
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P1([4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(5)', 'P8(17)', 'P5(12)', 'P2(37)']
#
#
# Clock: 138
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P1([4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(4)', 'P8(16)', 'P5(11)', 'P2(36)']
#
#
# Clock: 139
# Running Process: P6 Burst Time: 7
# Ready Queue: ['P1([4, 18, 6, 22, 4, 26, 3, 24, 4])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(3)', 'P8(15)', 'P5(10)', 'P2(35)']
#
#
# Clock: 140
# Running Process: P1 Burst Time: 4
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(2)', 'P8(14)', 'P5(9)', 'P2(34)', 'P6(13)']
#
#
# Clock: 141
# Running Process: P1 Burst Time: 4
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P4(1)', 'P8(13)', 'P5(8)', 'P2(33)', 'P6(12)']
#
#
# Clock: 142
# Running Process: P1 Burst Time: 4
# Ready Queue: ['P4([3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(12)', 'P5(7)', 'P2(32)', 'P6(11)']
#
#
# Clock: 143
# Running Process: P1 Burst Time: 4
# Ready Queue: ['P4([3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])', 'P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(11)', 'P5(6)', 'P2(31)', 'P6(10)']
#
#
# Clock: 144
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(10)', 'P5(5)', 'P2(30)', 'P6(9)', 'P1(17)']
#
#
# Clock: 145
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(9)', 'P5(4)', 'P2(29)', 'P6(8)', 'P1(16)']
#
#
# Clock: 146
# Running Process: P4 Burst Time: 3
# Ready Queue: ['P7([17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(8)', 'P5(3)', 'P2(28)', 'P6(7)', 'P1(15)']
#
#
# Clock: 147
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(7)', 'P5(2)', 'P2(27)', 'P6(6)', 'P1(14)', 'P4(50)']
#
#
# Clock: 148
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(6)', 'P5(1)', 'P2(26)', 'P6(5)', 'P1(13)', 'P4(49)']
#
#
# Clock: 149
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(5)', 'P2(25)', 'P6(4)', 'P1(12)', 'P4(48)']
#
#
# Clock: 150
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(4)', 'P2(24)', 'P6(3)', 'P1(11)', 'P4(47)']
#
#
# Clock: 151
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(3)', 'P2(23)', 'P6(2)', 'P1(10)', 'P4(46)']
#
#
# Clock: 152
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(2)', 'P2(22)', 'P6(1)', 'P1(9)', 'P4(45)']
#
#
# Clock: 153
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P8(1)', 'P2(21)', 'P1(8)', 'P4(44)']
#
#
# Clock: 154
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(20)', 'P1(7)', 'P4(43)']
#
#
# Clock: 155
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(19)', 'P1(6)', 'P4(42)']
#
#
# Clock: 156
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(18)', 'P1(5)', 'P4(41)']
#
#
# Clock: 157
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(17)', 'P1(4)', 'P4(40)']
#
#
# Clock: 158
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(16)', 'P1(3)', 'P4(39)']
#
#
# Clock: 159
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(15)', 'P1(2)', 'P4(38)']
#
#
# Clock: 160
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(14)', 'P1(1)', 'P4(37)']
#
#
# Clock: 161
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P1([6, 22, 4, 26, 3, 24, 4])', 'P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(13)', 'P4(36)']
#
#
# Clock: 162
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P1([6, 22, 4, 26, 3, 24, 4])', 'P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(12)', 'P4(35)']
#
#
# Clock: 163
# Running Process: P7 Burst Time: 17
# Ready Queue: ['P1([6, 22, 4, 26, 3, 24, 4])', 'P6([9, 18, 12, 24, 15, 30, 8])', 'P8([14, 73, 16, 87, 6])', 'P5([17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P3([18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(11)', 'P4(34)']
#
#
# Clock: 164
# Running Process: P1 Burst Time: 6
# ...
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(11)', 'P4(50)', 'P3(8)']
#
#
# Clock: 481
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(10)', 'P4(49)', 'P3(7)']
#
#
# Clock: 482
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(9)', 'P4(48)', 'P3(6)']
#
#
# Clock: 483
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(8)', 'P4(47)', 'P3(5)']
#
#
# Clock: 484
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(7)', 'P4(46)', 'P3(4)']
#
#
# Clock: 485
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(6)', 'P4(45)', 'P3(3)']
#
#
# Clock: 486
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(5)', 'P4(44)', 'P3(2)']
#
#
# Clock: 487
# Running Process: P5 Burst Time: 11
# Ready Queue: []
# I/O Queue: ['P2(4)', 'P4(43)', 'P3(1)']
#
#
# Clock: 488
# Running Process: P5 Burst Time: 11
# Ready Queue: ['P3([4, 61, 15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: ['P2(3)', 'P4(42)']
#
#
# Clock: 489
# Running Process: P3 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P2(2)', 'P4(41)', 'P5(20)']
#
#
# Clock: 490
# Running Process: P3 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P2(1)', 'P4(40)', 'P5(19)']
#
#
# Clock: 491
# Running Process: P3 Burst Time: 4
# Ready Queue: ['P2([8])']
# I/O Queue: ['P4(39)', 'P5(18)']
#
#
# Clock: 492
# Running Process: P3 Burst Time: 4
# Ready Queue: ['P2([8])']
# I/O Queue: ['P4(38)', 'P5(17)']
#
#
# Clock: 493
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(37)', 'P5(16)', 'P3(60)']
#
#
# Clock: 494
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(36)', 'P5(15)', 'P3(59)']
#
#
# Clock: 495
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(35)', 'P5(14)', 'P3(58)']
#
#
# Clock: 496
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(34)', 'P5(13)', 'P3(57)']
#
#
# Clock: 497
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(33)', 'P5(12)', 'P3(56)']
#
#
# Clock: 498
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(32)', 'P5(11)', 'P3(55)']
#
#
# Clock: 499
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(31)', 'P5(10)', 'P3(54)']
#
#
# Clock: 500
# Running Process: P2 Burst Time: 8
# Ready Queue: []
# I/O Queue: ['P4(30)', 'P5(9)', 'P3(53)']
#
#
# Process P2 has completed its total execution.
# Clock: 501
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(29)', 'P5(8)', 'P3(52)']
#
#
# Clock: 502
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(28)', 'P5(7)', 'P3(51)']
#
#
# Clock: 503
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(27)', 'P5(6)', 'P3(50)']
#
#
# Clock: 504
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(26)', 'P5(5)', 'P3(49)']
#
#
# Clock: 505
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(25)', 'P5(4)', 'P3(48)']
#
#
# Clock: 506
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(24)', 'P5(3)', 'P3(47)']
#
#
# Clock: 507
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(23)', 'P5(2)', 'P3(46)']
#
#
# Clock: 508
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(22)', 'P5(1)', 'P3(45)']
#
#
# Clock: 509
# Running Process: None
# Ready Queue: ['P5([6, 13, 3, 11, 4])']
# I/O Queue: ['P4(21)', 'P3(44)']
#
#
# Clock: 510
# Running Process: P5 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(20)', 'P3(43)']
#
#
# Clock: 511
# Running Process: P5 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(19)', 'P3(42)']
#
#
# Clock: 512
# Running Process: P5 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(18)', 'P3(41)']
#
#
# Clock: 513
# Running Process: P5 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(17)', 'P3(40)']
#
#
# Clock: 514
# Running Process: P5 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(16)', 'P3(39)']
#
#
# Clock: 515
# Running Process: P5 Burst Time: 6
# Ready Queue: []
# I/O Queue: ['P4(15)', 'P3(38)']
#
#
# Clock: 516
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(14)', 'P3(37)', 'P5(12)']
#
#
# Clock: 517
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(13)', 'P3(36)', 'P5(11)']
#
#
# Clock: 518
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(12)', 'P3(35)', 'P5(10)']
#
#
# Clock: 519
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(11)', 'P3(34)', 'P5(9)']
#
#
# Clock: 520
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(10)', 'P3(33)', 'P5(8)']
#
#
# Clock: 521
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(9)', 'P3(32)', 'P5(7)']
#
#
# Clock: 522
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(8)', 'P3(31)', 'P5(6)']
#
#
# Clock: 523
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(7)', 'P3(30)', 'P5(5)']
#
#
# Clock: 524
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(6)', 'P3(29)', 'P5(4)']
#
#
# Clock: 525
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(5)', 'P3(28)', 'P5(3)']
#
#
# Clock: 526
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(4)', 'P3(27)', 'P5(2)']
#
#
# Clock: 527
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P4(3)', 'P3(26)', 'P5(1)']
#
#
# Clock: 528
# Running Process: None
# Ready Queue: ['P5([3, 11, 4])']
# I/O Queue: ['P4(2)', 'P3(25)']
#
#
# Clock: 529
# Running Process: P5 Burst Time: 3
# Ready Queue: []
# I/O Queue: ['P4(1)', 'P3(24)']
#
#
# Clock: 530
# Running Process: P5 Burst Time: 3
# Ready Queue: ['P4([3])']
# I/O Queue: ['P3(23)']
#
#
# Clock: 531
# Running Process: P5 Burst Time: 3
# Ready Queue: ['P4([3])']
# I/O Queue: ['P3(22)']
#
#
# Clock: 532
# Running Process: P4 Burst Time: 3
# Ready Queue: []
# I/O Queue: ['P3(21)', 'P5(10)']
#
#
# Clock: 533
# Running Process: P4 Burst Time: 3
# Ready Queue: []
# I/O Queue: ['P3(20)', 'P5(9)']
#
#
# Clock: 534
# Running Process: P4 Burst Time: 3
# Ready Queue: []
# I/O Queue: ['P3(19)', 'P5(8)']
#
#
# Process P4 has completed its total execution.
# Clock: 535
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(18)', 'P5(7)']
#
#
# Clock: 536
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(17)', 'P5(6)']
#
#
# Clock: 537
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(16)', 'P5(5)']
#
#
# Clock: 538
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(15)', 'P5(4)']
#
#
# Clock: 539
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(14)', 'P5(3)']
#
#
# Clock: 540
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(13)', 'P5(2)']
#
#
# Clock: 541
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(12)', 'P5(1)']
#
#
# Clock: 542
# Running Process: None
# Ready Queue: ['P5([4])']
# I/O Queue: ['P3(11)']
#
#
# Clock: 543
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P3(10)']
#
#
# Clock: 544
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P3(9)']
#
#
# Clock: 545
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P3(8)']
#
#
# Clock: 546
# Running Process: P5 Burst Time: 4
# Ready Queue: []
# I/O Queue: ['P3(7)']
#
#
# Process P5 has completed its total execution.
# Clock: 547
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(6)']
#
#
# Clock: 548
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(5)']
#
#
# Clock: 549
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(4)']
#
#
# Clock: 550
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(3)']
#
#
# Clock: 551
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(2)']
#
#
# Clock: 552
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(1)']
#
#
# Clock: 553
# Running Process: None
# Ready Queue: ['P3([15, 18, 14, 26, 5, 31, 6])']
# I/O Queue: []
#
#
# Clock: 554
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 555
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 556
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 557
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 558
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 559
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 560
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 561
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 562
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 563
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 564
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 565
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 566
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 567
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 568
# Running Process: P3 Burst Time: 15
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 569
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(17)']
#
#
# Clock: 570
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(16)']
#
#
# Clock: 571
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(15)']
#
#
# Clock: 572
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(14)']
#
#
# Clock: 573
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(13)']
#
#
# Clock: 574
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(12)']
#
#
# Clock: 575
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(11)']
#
#
# Clock: 576
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(10)']
#
#
# Clock: 577
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(9)']
#
#
# Clock: 578
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(8)']
#
#
# Clock: 579
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(7)']
#
#
# Clock: 580
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(6)']
#
#
# Clock: 581
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(5)']
#
#
# Clock: 582
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(4)']
#
#
# Clock: 583
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(3)']
#
#
# Clock: 584
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(2)']
#
#
# Clock: 585
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(1)']
#
#
# Clock: 586
# Running Process: None
# Ready Queue: ['P3([14, 26, 5, 31, 6])']
# I/O Queue: []
#
#
# Clock: 587
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 588
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 589
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 590
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 591
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 592
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 593
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 594
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 595
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 596
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 597
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 598
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 599
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 600
# Running Process: P3 Burst Time: 14
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 601
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(25)']
#
#
# Clock: 602
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(24)']
#
#
# Clock: 603
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(23)']
#
#
# Clock: 604
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(22)']
#
#
# Clock: 605
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(21)']
#
#
# Clock: 606
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(20)']
#
#
# Clock: 607
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(19)']
#
#
# Clock: 608
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(18)']
#
#
# Clock: 609
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(17)']
#
#
# Clock: 610
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(16)']
#
#
# Clock: 611
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(15)']
#
#
# Clock: 612
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(14)']
#
#
# Clock: 613
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(13)']
#
#
# Clock: 614
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(12)']
#
#
# Clock: 615
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(11)']
#
#
# Clock: 616
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(10)']
#
#
# Clock: 617
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(9)']
#
#
# Clock: 618
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(8)']
#
#
# Clock: 619
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(7)']
#
#
# Clock: 620
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(6)']
#
#
# Clock: 621
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(5)']
#
#
# Clock: 622
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(4)']
#
#
# Clock: 623
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(3)']
#
#
# Clock: 624
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(2)']
#
#
# Clock: 625
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(1)']
#
#
# Clock: 626
# Running Process: None
# Ready Queue: ['P3([5, 31, 6])']
# I/O Queue: []
#
#
# Clock: 627
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 628
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 629
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 630
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 631
# Running Process: P3 Burst Time: 5
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 632
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(30)']
#
#
# Clock: 633
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(29)']
#
#
# Clock: 634
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(28)']
#
#
# Clock: 635
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(27)']
#
#
# Clock: 636
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(26)']
#
#
# Clock: 637
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(25)']
#
#
# Clock: 638
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(24)']
#
#
# Clock: 639
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(23)']
#
#
# Clock: 640
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(22)']
#
#
# Clock: 641
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(21)']
#
#
# Clock: 642
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(20)']
#
#
# Clock: 643
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(19)']
#
#
# Clock: 644
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(18)']
#
#
# Clock: 645
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(17)']
#
#
# Clock: 646
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(16)']
#
#
# Clock: 647
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(15)']
#
#
# Clock: 648
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(14)']
#
#
# Clock: 649
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(13)']
#
#
# Clock: 650
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(12)']
#
#
# Clock: 651
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(11)']
#
#
# Clock: 652
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(10)']
#
#
# Clock: 653
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(9)']
#
#
# Clock: 654
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(8)']
#
#
# Clock: 655
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(7)']
#
#
# Clock: 656
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(6)']
#
#
# Clock: 657
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(5)']
#
#
# Clock: 658
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(4)']
#
#
# Clock: 659
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(3)']
#
#
# Clock: 660
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(2)']
#
#
# Clock: 661
# Running Process: None
# Ready Queue: []
# I/O Queue: ['P3(1)']
#
#
# Clock: 662
# Running Process: None
# Ready Queue: ['P3([6])']
# I/O Queue: []
#
#
# Clock: 663
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 664
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 665
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 666
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 667
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: []
#
#
# Clock: 668
# Running Process: P3 Burst Time: 6
# Ready Queue: []
# I/O Queue: []
#
#
# Process P3 has completed its total execution.
# Process	Waiting Time	Turnaround Time	Response Time
# P1	43		268		11
# P2	73		500		3
# P3	276		668		16
# P4	50		534		0
# P5	237		546		109
# P6	121		336		24
# P7	149		477		47
# P8	119		428		7
#
# Average Waiting Time: 133.5
# Average Turnaround Time: 469.625
# Average Response Time: 27.125
# CPU Utilization: 0.8266068759342302%
# Total Run Time: 669

# %% [markdown]
# MLFQ

# %%
"""
The process class stores each processes CPU and I/O bursts, process id, total burst time,
wait time, turnaround time, and response time.
"""
class Process:

    def __init__(self, pid, bursts):
        self.pid = pid
        self.bursts = bursts
        self.total_burst_time = sum(bursts) #Total burst time to calculate wait time
        self.wait_time = 0
        self.turnaround_time = 0
        self.response_time = 1 #Set to 1 initially

P1 = Process(1, [5, 27, 3, 31, 5, 43, 4, 18, 6, 22, 4, 26, 3, 24, 4])
P2 = Process(2, [4, 48, 5, 44, 7, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])
P3 = Process(3, [8, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])
P4 = Process(4, [3, 35, 4, 41, 5, 45, 3, 51, 4, 61, 5, 54, 6, 82, 5, 77, 3])
P5 = Process(5, [16, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])
P6 = Process(6, [11, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])
P7 = Process(7, [14, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])
P8 = Process(8, [4, 14, 5, 33, 6, 51, 14, 73, 16, 87, 6])

processes = [P1, P2, P3, P4, P5, P6, P7, P8]

#Total for cpu bursts to later calculate cpu utilization
burst_time = 553

# %%
def mlfq(processes):
    clock = 0

    queue1 = processes.copy() #Initialzes a copy of all processes that start in RR queue 1
    queue2 = []
    queue3 = []
    io_queue = []

    running_process = 0 #0 means no process is running
    running_time = 0
    tq1 = 5
    tq2 = 10
    tq_count = 0 #used to keep track of tq time

    def printExecution():
      #Prints the current run time, the current running process, and the ready / IO queues
      print(f"Clock: {clock}")

      if running_process == 0:
          print("Running Process: None")
      else:
          print(f"Running Process: P{running_process.pid} Burst Time: {running_process.bursts[0]}")

      print("Queue 1:", [f"P{p.pid}({p.bursts})" for p in queue2])
      print("Queue 2:", [f"P{p.pid}({p.bursts})" for p in queue2])
      print("Queue 3:", [f"P{p.pid}({p.bursts})" for p in queue3])
      print("I/O Queue:", [f"P{p[0].pid}({p[1]})" for p in io_queue])
      print("\n")

    #checks if there are processes in ready queue, io queue, or if a process is currently running
    while len(queue1) > 0 or len(queue2) > 0 or len(queue3) > 0 or len(io_queue) > 0  or running_process !=  0:

        printExecution()

        #If no process is running it checks all the queues
        if running_process == 0:
            if queue1:
                running_process = queue1.pop(0)
                running_time = 0
                tq_count = tq1

            elif queue2:
                running_process = queue2.pop(0)
                running_time = 0
                tq_count = tq2

            elif queue3:
                running_process = queue3.pop(0)
                running_time = 0

        #Checsk if a process is running
        if running_process != 0:

            if running_process.response_time == 1:
              #All processes are initialized with a response time of 1
              #This then sets the response time to the clock value if its their first time running
                running_process.response_time = clock

            #Subtracts from the current processes cpu burst and increments run time
            running_process.bursts[0] -= 1
            running_time += 1
            #Checks if a burst is finished and removes  it
            if running_process.bursts[0] == 0:
                running_process.bursts.pop(0)
                #If a process has more burst after the cpu, it is added to the I/O queue
                if running_process.bursts:
                    io_time = running_process.bursts.pop(0)
                    io_queue.append((running_process, io_time))

                else:
                    #Else a process is finished, assigns turnaround time
                    running_process.turnaround_time = clock
                    print(f"Process P{running_process.pid} has completed its total execution.")
                #Resets running process and time
                running_process = 0
                running_time = 0
            #Checks if a run time reaches a tq count
            elif running_time == tq_count:
                #If a process in queue 1 exceeds tq(5), the process is added to RR queue 2
                if tq_count == tq1:
                    queue2.append(running_process)
                #If a process in queue 2 exceeds tq(10), the process is added to FCFS queue 3
                elif tq_count == tq2:
                    queue3.append(running_process)
                #Resets running process and time
                running_process = 0
                running_time = 0



        #creates a new io queue
        new_io_queue = []
        #checks if a process still has time left for its io burst
        for p, time_left in io_queue:
          #decreases the cpu bursts by 1
            time_left -= 1
            #Checks if a I/O burst is done
            if time_left == 0:
                #Removes the process and adds it back to queue 1
                queue1.append(p)
          #else the remaining processes are added to a new queue to finish their io bursts
            else:
                 new_io_queue.append((p, time_left))
        #remakes the io queue and increments the clock by 1
        io_queue = new_io_queue
        clock += 1
    #Calculates wait time for all processes
    for p in processes:
            p.wait_time = p.turnaround_time - p.total_burst_time

    #returns each process instance and the final run time
    return processes, clock

def generateStats(processData, clock):
    # Prints all the final stats
    avg_wait_time = sum(p.wait_time for p in processData) / 8
    avg_turnaround_time = sum(p.turnaround_time for p in processData) / 8
    avg_response_time = sum(p.response_time for p in processData) / 8
    cpu_utilization = (burst_time / clock)

    print("Process\tWaiting Time\tTurnaround Time\tResponse Time")
    for p in processData:
        print(f"P{p.pid}\t{p.wait_time}\t\t{p.turnaround_time}\t\t{p.response_time}")
    print(f"\nAverage Waiting Time: {avg_wait_time}")
    print(f"Average Turnaround Time: {avg_turnaround_time}")
    print(f"Average Response Time: {avg_response_time}")
    print(f"CPU Utilization: {cpu_utilization}%")
    print(f"Total Run Time: {clock}")

if __name__ == "__main__":

  processData, clock = mlfq(processes)
  generateStats(processData, clock)
# Out:
# Clock: 0
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 1
# Running Process: P1 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 2
# Running Process: P1 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 3
# Running Process: P1 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 4
# Running Process: P1 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 5
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(26)']
#
#
# Clock: 6
# Running Process: P2 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(25)']
#
#
# Clock: 7
# Running Process: P2 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(24)']
#
#
# Clock: 8
# Running Process: P2 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(23)']
#
#
# Clock: 9
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(22)', 'P2(47)']
#
#
# Clock: 10
# Running Process: P3 Burst Time: 7
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(21)', 'P2(46)']
#
#
# Clock: 11
# Running Process: P3 Burst Time: 6
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(20)', 'P2(45)']
#
#
# Clock: 12
# Running Process: P3 Burst Time: 5
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(19)', 'P2(44)']
#
#
# Clock: 13
# Running Process: P3 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P1(18)', 'P2(43)']
#
#
# Clock: 14
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(17)', 'P2(42)']
#
#
# Clock: 15
# Running Process: P4 Burst Time: 2
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(16)', 'P2(41)']
#
#
# Clock: 16
# Running Process: P4 Burst Time: 1
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(15)', 'P2(40)']
#
#
# Clock: 17
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(14)', 'P2(39)', 'P4(34)']
#
#
# Clock: 18
# Running Process: P5 Burst Time: 15
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(13)', 'P2(38)', 'P4(33)']
#
#
# Clock: 19
# Running Process: P5 Burst Time: 14
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(12)', 'P2(37)', 'P4(32)']
#
#
# Clock: 20
# Running Process: P5 Burst Time: 13
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(11)', 'P2(36)', 'P4(31)']
#
#
# Clock: 21
# Running Process: P5 Burst Time: 12
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P1(10)', 'P2(35)', 'P4(30)']
#
#
# Clock: 22
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 3: []
# I/O Queue: ['P1(9)', 'P2(34)', 'P4(29)']
#
#
# Clock: 23
# Running Process: P6 Burst Time: 10
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 3: []
# I/O Queue: ['P1(8)', 'P2(33)', 'P4(28)']
#
#
# Clock: 24
# Running Process: P6 Burst Time: 9
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 3: []
# I/O Queue: ['P1(7)', 'P2(32)', 'P4(27)']
#
#
# Clock: 25
# Running Process: P6 Burst Time: 8
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 3: []
# I/O Queue: ['P1(6)', 'P2(31)', 'P4(26)']
#
#
# Clock: 26
# Running Process: P6 Burst Time: 7
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# Queue 3: []
# I/O Queue: ['P1(5)', 'P2(30)', 'P4(25)']
#
#
# Clock: 27
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: []
# I/O Queue: ['P1(4)', 'P2(29)', 'P4(24)']
#
#
# Clock: 28
# Running Process: P7 Burst Time: 13
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: []
# I/O Queue: ['P1(3)', 'P2(28)', 'P4(23)']
#
#
# Clock: 29
# Running Process: P7 Burst Time: 12
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: []
# I/O Queue: ['P1(2)', 'P2(27)', 'P4(22)']
#
#
# Clock: 30
# Running Process: P7 Burst Time: 11
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: []
# I/O Queue: ['P1(1)', 'P2(26)', 'P4(21)']
#
#
# Clock: 31
# Running Process: P7 Burst Time: 10
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: []
# I/O Queue: ['P2(25)', 'P4(20)']
#
#
# Clock: 32
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(24)', 'P4(19)']
#
#
# Clock: 33
# Running Process: P8 Burst Time: 3
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(23)', 'P4(18)']
#
#
# Clock: 34
# Running Process: P8 Burst Time: 2
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(22)', 'P4(17)']
#
#
# Clock: 35
# Running Process: P8 Burst Time: 1
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(21)', 'P4(16)']
#
#
# Clock: 36
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(20)', 'P4(15)', 'P8(13)']
#
#
# Clock: 37
# Running Process: P1 Burst Time: 2
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(19)', 'P4(14)', 'P8(12)']
#
#
# Clock: 38
# Running Process: P1 Burst Time: 1
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(18)', 'P4(13)', 'P8(11)']
#
#
# Clock: 39
# Running Process: None
# Queue 1: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P3([3, 33, 12, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(17)', 'P4(12)', 'P8(10)', 'P1(30)']
#
#
# Clock: 40
# Running Process: P3 Burst Time: 2
# Queue 1: ['P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(16)', 'P4(11)', 'P8(9)', 'P1(29)']
#
#
# Clock: 41
# Running Process: P3 Burst Time: 1
# Queue 1: ['P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(15)', 'P4(10)', 'P8(8)', 'P1(28)']
#
#
# Clock: 42
# Running Process: None
# Queue 1: ['P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P5([11, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])', 'P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(14)', 'P4(9)', 'P8(7)', 'P1(27)', 'P3(32)']
#
#
# Clock: 43
# Running Process: P5 Burst Time: 10
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(13)', 'P4(8)', 'P8(6)', 'P1(26)', 'P3(31)']
#
#
# Clock: 44
# Running Process: P5 Burst Time: 9
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(12)', 'P4(7)', 'P8(5)', 'P1(25)', 'P3(30)']
#
#
# Clock: 45
# Running Process: P5 Burst Time: 8
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(11)', 'P4(6)', 'P8(4)', 'P1(24)', 'P3(29)']
#
#
# Clock: 46
# Running Process: P5 Burst Time: 7
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(10)', 'P4(5)', 'P8(3)', 'P1(23)', 'P3(28)']
#
#
# Clock: 47
# Running Process: P5 Burst Time: 6
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(9)', 'P4(4)', 'P8(2)', 'P1(22)', 'P3(27)']
#
#
# Clock: 48
# Running Process: P5 Burst Time: 5
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(8)', 'P4(3)', 'P8(1)', 'P1(21)', 'P3(26)']
#
#
# Clock: 49
# Running Process: P5 Burst Time: 4
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(7)', 'P4(2)', 'P1(20)', 'P3(25)']
#
#
# Clock: 50
# Running Process: P5 Burst Time: 3
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(6)', 'P4(1)', 'P1(19)', 'P3(24)']
#
#
# Clock: 51
# Running Process: P5 Burst Time: 2
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(5)', 'P1(18)', 'P3(23)']
#
#
# Clock: 52
# Running Process: None
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(4)', 'P1(17)', 'P3(22)']
#
#
# Clock: 53
# Running Process: P8 Burst Time: 4
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(3)', 'P1(16)', 'P3(21)']
#
#
# Clock: 54
# Running Process: P8 Burst Time: 3
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(2)', 'P1(15)', 'P3(20)']
#
#
# Clock: 55
# Running Process: P8 Burst Time: 2
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(1)', 'P1(14)', 'P3(19)']
#
#
# Clock: 56
# Running Process: P8 Burst Time: 1
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(13)', 'P3(18)']
#
#
# Clock: 57
# Running Process: None
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(12)', 'P3(17)', 'P8(32)']
#
#
# Clock: 58
# Running Process: P4 Burst Time: 3
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(11)', 'P3(16)', 'P8(31)']
#
#
# Clock: 59
# Running Process: P4 Burst Time: 2
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(10)', 'P3(15)', 'P8(30)']
#
#
# Clock: 60
# Running Process: P4 Burst Time: 1
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(9)', 'P3(14)', 'P8(29)']
#
#
# Clock: 61
# Running Process: None
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(8)', 'P3(13)', 'P8(28)', 'P4(40)']
#
#
# Clock: 62
# Running Process: P2 Burst Time: 4
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(7)', 'P3(12)', 'P8(27)', 'P4(39)']
#
#
# Clock: 63
# Running Process: P2 Burst Time: 3
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(6)', 'P3(11)', 'P8(26)', 'P4(38)']
#
#
# Clock: 64
# Running Process: P2 Burst Time: 2
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(5)', 'P3(10)', 'P8(25)', 'P4(37)']
#
#
# Clock: 65
# Running Process: P2 Burst Time: 1
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(4)', 'P3(9)', 'P8(24)', 'P4(36)']
#
#
# Clock: 66
# Running Process: None
# Queue 1: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P6([6, 22, 4, 8, 5, 10, 6, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])', 'P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(3)', 'P3(8)', 'P8(23)', 'P4(35)', 'P2(43)']
#
#
# Clock: 67
# Running Process: P6 Burst Time: 5
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(2)', 'P3(7)', 'P8(22)', 'P4(34)', 'P2(42)']
#
#
# Clock: 68
# Running Process: P6 Burst Time: 4
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(1)', 'P3(6)', 'P8(21)', 'P4(33)', 'P2(41)']
#
#
# Clock: 69
# Running Process: P6 Burst Time: 3
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(5)', 'P8(20)', 'P4(32)', 'P2(40)']
#
#
# Clock: 70
# Running Process: P6 Burst Time: 2
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(4)', 'P8(19)', 'P4(31)', 'P2(39)']
#
#
# Clock: 71
# Running Process: P6 Burst Time: 1
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(3)', 'P8(18)', 'P4(30)', 'P2(38)']
#
#
# Clock: 72
# Running Process: None
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(2)', 'P8(17)', 'P4(29)', 'P2(37)', 'P6(21)']
#
#
# Clock: 73
# Running Process: P1 Burst Time: 4
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P3(1)', 'P8(16)', 'P4(28)', 'P2(36)', 'P6(20)']
#
#
# Clock: 74
# Running Process: P1 Burst Time: 3
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(15)', 'P4(27)', 'P2(35)', 'P6(19)']
#
#
# Clock: 75
# Running Process: P1 Burst Time: 2
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(14)', 'P4(26)', 'P2(34)', 'P6(18)']
#
#
# Clock: 76
# Running Process: P1 Burst Time: 1
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(13)', 'P4(25)', 'P2(33)', 'P6(17)']
#
#
# Clock: 77
# Running Process: None
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(12)', 'P4(24)', 'P2(32)', 'P6(16)', 'P1(42)']
#
#
# Clock: 78
# Running Process: P3 Burst Time: 11
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(11)', 'P4(23)', 'P2(31)', 'P6(15)', 'P1(41)']
#
#
# Clock: 79
# Running Process: P3 Burst Time: 10
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(10)', 'P4(22)', 'P2(30)', 'P6(14)', 'P1(40)']
#
#
# Clock: 80
# Running Process: P3 Burst Time: 9
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(9)', 'P4(21)', 'P2(29)', 'P6(13)', 'P1(39)']
#
#
# Clock: 81
# Running Process: P3 Burst Time: 8
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(8)', 'P4(20)', 'P2(28)', 'P6(12)', 'P1(38)']
#
#
# Clock: 82
# Running Process: None
# Queue 1: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P7([9, 46, 17, 41, 11, 42, 15, 21, 4, 32, 7, 19, 16, 33, 10])', 'P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(7)', 'P4(19)', 'P2(27)', 'P6(11)', 'P1(37)']
#
#
# Clock: 83
# Running Process: P7 Burst Time: 8
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(6)', 'P4(18)', 'P2(26)', 'P6(10)', 'P1(36)']
#
#
# Clock: 84
# Running Process: P7 Burst Time: 7
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(5)', 'P4(17)', 'P2(25)', 'P6(9)', 'P1(35)']
#
#
# Clock: 85
# Running Process: P7 Burst Time: 6
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(4)', 'P4(16)', 'P2(24)', 'P6(8)', 'P1(34)']
#
#
# Clock: 86
# Running Process: P7 Burst Time: 5
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(3)', 'P4(15)', 'P2(23)', 'P6(7)', 'P1(33)']
#
#
# Clock: 87
# Running Process: P7 Burst Time: 4
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(2)', 'P4(14)', 'P2(22)', 'P6(6)', 'P1(32)']
#
#
# Clock: 88
# Running Process: P7 Burst Time: 3
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P8(1)', 'P4(13)', 'P2(21)', 'P6(5)', 'P1(31)']
#
#
# Clock: 89
# Running Process: P7 Burst Time: 2
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(12)', 'P2(20)', 'P6(4)', 'P1(30)']
#
#
# Clock: 90
# Running Process: P7 Burst Time: 1
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(11)', 'P2(19)', 'P6(3)', 'P1(29)']
#
#
# Clock: 91
# Running Process: None
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(10)', 'P2(18)', 'P6(2)', 'P1(28)', 'P7(45)']
#
#
# Clock: 92
# Running Process: P8 Burst Time: 5
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(9)', 'P2(17)', 'P6(1)', 'P1(27)', 'P7(44)']
#
#
# Clock: 93
# Running Process: P8 Burst Time: 4
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(8)', 'P2(16)', 'P1(26)', 'P7(43)']
#
#
# Clock: 94
# Running Process: P8 Burst Time: 3
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(7)', 'P2(15)', 'P1(25)', 'P7(42)']
#
#
# Clock: 95
# Running Process: P8 Burst Time: 2
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(6)', 'P2(14)', 'P1(24)', 'P7(41)']
#
#
# Clock: 96
# Running Process: None
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(5)', 'P2(13)', 'P1(23)', 'P7(40)']
#
#
# Clock: 97
# Running Process: P6 Burst Time: 3
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(4)', 'P2(12)', 'P1(22)', 'P7(39)']
#
#
# Clock: 98
# Running Process: P6 Burst Time: 2
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(3)', 'P2(11)', 'P1(21)', 'P7(38)']
#
#
# Clock: 99
# Running Process: P6 Burst Time: 1
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(2)', 'P2(10)', 'P1(20)', 'P7(37)']
#
#
# Clock: 100
# Running Process: None
# Queue 1: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P3([7, 41, 18, 65, 14, 21, 4, 61, 15, 18, 14, 26, 5, 31, 6])', 'P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P4(1)', 'P2(9)', 'P1(19)', 'P7(36)', 'P6(7)']
#
#
# Clock: 101
# Running Process: P3 Burst Time: 6
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(8)', 'P1(18)', 'P7(35)', 'P6(6)']
#
#
# Clock: 102
# Running Process: P3 Burst Time: 5
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(7)', 'P1(17)', 'P7(34)', 'P6(5)']
#
#
# Clock: 103
# Running Process: P3 Burst Time: 4
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(6)', 'P1(16)', 'P7(33)', 'P6(4)']
#
#
# Clock: 104
# Running Process: P3 Burst Time: 3
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(5)', 'P1(15)', 'P7(32)', 'P6(3)']
#
#
# Clock: 105
# Running Process: P3 Burst Time: 2
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(4)', 'P1(14)', 'P7(31)', 'P6(2)']
#
#
# Clock: 106
# Running Process: P3 Burst Time: 1
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(3)', 'P1(13)', 'P7(30)', 'P6(1)']
#
#
# Clock: 107
# Running Process: None
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(2)', 'P1(12)', 'P7(29)', 'P3(40)']
#
#
# Clock: 108
# Running Process: P4 Burst Time: 4
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P2(1)', 'P1(11)', 'P7(28)', 'P3(39)']
#
#
# Clock: 109
# Running Process: P4 Burst Time: 3
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(10)', 'P7(27)', 'P3(38)']
#
#
# Clock: 110
# Running Process: P4 Burst Time: 2
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(9)', 'P7(26)', 'P3(37)']
#
#
# Clock: 111
# Running Process: P4 Burst Time: 1
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(8)', 'P7(25)', 'P3(36)']
#
#
# Clock: 112
# Running Process: None
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(7)', 'P7(24)', 'P3(35)', 'P4(44)']
#
#
# Clock: 113
# Running Process: P6 Burst Time: 4
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(6)', 'P7(23)', 'P3(34)', 'P4(43)']
#
#
# Clock: 114
# Running Process: P6 Burst Time: 3
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(5)', 'P7(22)', 'P3(33)', 'P4(42)']
#
#
# Clock: 115
# Running Process: P6 Burst Time: 2
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(4)', 'P7(21)', 'P3(32)', 'P4(41)']
#
#
# Clock: 116
# Running Process: P6 Burst Time: 1
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(3)', 'P7(20)', 'P3(31)', 'P4(40)']
#
#
# Clock: 117
# Running Process: None
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(2)', 'P7(19)', 'P3(30)', 'P4(39)', 'P6(9)']
#
#
# Clock: 118
# Running Process: P2 Burst Time: 6
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P1(1)', 'P7(18)', 'P3(29)', 'P4(38)', 'P6(8)']
#
#
# Clock: 119
# Running Process: P2 Burst Time: 5
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(17)', 'P3(28)', 'P4(37)', 'P6(7)']
#
#
# Clock: 120
# Running Process: P2 Burst Time: 4
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(16)', 'P3(27)', 'P4(36)', 'P6(6)']
#
#
# Clock: 121
# Running Process: P2 Burst Time: 3
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(15)', 'P3(26)', 'P4(35)', 'P6(5)']
#
#
# Clock: 122
# Running Process: None
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(14)', 'P3(25)', 'P4(34)', 'P6(4)']
#
#
# Clock: 123
# Running Process: P1 Burst Time: 3
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(13)', 'P3(24)', 'P4(33)', 'P6(3)']
#
#
# Clock: 124
# Running Process: P1 Burst Time: 2
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(12)', 'P3(23)', 'P4(32)', 'P6(2)']
#
#
# Clock: 125
# Running Process: P1 Burst Time: 1
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(11)', 'P3(22)', 'P4(31)', 'P6(1)']
#
#
# Clock: 126
# Running Process: None
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(10)', 'P3(21)', 'P4(30)', 'P1(17)']
#
#
# Clock: 127
# Running Process: P6 Burst Time: 5
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(9)', 'P3(20)', 'P4(29)', 'P1(16)']
#
#
# Clock: 128
# Running Process: P6 Burst Time: 4
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(8)', 'P3(19)', 'P4(28)', 'P1(15)']
#
#
# Clock: 129
# Running Process: P6 Burst Time: 3
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(7)', 'P3(18)', 'P4(27)', 'P1(14)']
#
#
# Clock: 130
# Running Process: P6 Burst Time: 2
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(6)', 'P3(17)', 'P4(26)', 'P1(13)']
#
#
# Clock: 131
# Running Process: None
# Queue 1: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([1, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P8([1, 51, 14, 73, 16, 87, 6])', 'P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([1, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(5)', 'P3(16)', 'P4(25)', 'P1(12)']
#
#
# Clock: 132
# Running Process: None
# Queue 1: ['P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([1, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 2: ['P2([2, 42, 12, 37, 9, 76, 4, 41, 9, 31, 7, 43, 8])', 'P6([1, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# Queue 3: ['P5([1, 24, 17, 21, 5, 36, 16, 26, 7, 31, 13, 28, 11, 21, 6, 13, 3, 11, 4])']
# I/O Queue: ['P7(4)', 'P3(15)', 'P4(24)', 'P1(11)', 'P8(50)']
#
#
# Clock: 133
# Running Process: P2 Burst Time: 1
# Queue 1: ['P6([1, 12, 7, 14, 9, 18, 12, 24, 15, 30, 8])']
# ...
# Queue 3: []
# I/O Queue: ['P2(26)', 'P7(9)', 'P5(26)']
#
#
# Clock: 484
# Running Process: P4 Burst Time: 3
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(25)', 'P7(8)', 'P5(25)']
#
#
# Clock: 485
# Running Process: P4 Burst Time: 2
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(24)', 'P7(7)', 'P5(24)']
#
#
# Clock: 486
# Running Process: P4 Burst Time: 1
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(23)', 'P7(6)', 'P5(23)']
#
#
# Clock: 487
# Running Process: None
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(22)', 'P7(5)', 'P5(22)', 'P4(76)']
#
#
# Clock: 488
# Running Process: P8 Burst Time: 5
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(21)', 'P7(4)', 'P5(21)', 'P4(75)']
#
#
# Clock: 489
# Running Process: P8 Burst Time: 4
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(20)', 'P7(3)', 'P5(20)', 'P4(74)']
#
#
# Clock: 490
# Running Process: P8 Burst Time: 3
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(19)', 'P7(2)', 'P5(19)', 'P4(73)']
#
#
# Clock: 491
# Running Process: P8 Burst Time: 2
# Queue 1: ['P3([9, 26, 5, 31, 6])']
# Queue 2: ['P3([9, 26, 5, 31, 6])']
# Queue 3: []
# I/O Queue: ['P2(18)', 'P7(1)', 'P5(18)', 'P4(72)']
#
#
# Clock: 492
# Running Process: None
# Queue 1: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 2: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 3: []
# I/O Queue: ['P2(17)', 'P5(17)', 'P4(71)']
#
#
# Clock: 493
# Running Process: P7 Burst Time: 15
# Queue 1: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 2: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 3: []
# I/O Queue: ['P2(16)', 'P5(16)', 'P4(70)']
#
#
# Clock: 494
# Running Process: P7 Burst Time: 14
# Queue 1: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 2: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 3: []
# I/O Queue: ['P2(15)', 'P5(15)', 'P4(69)']
#
#
# Clock: 495
# Running Process: P7 Burst Time: 13
# Queue 1: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 2: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 3: []
# I/O Queue: ['P2(14)', 'P5(14)', 'P4(68)']
#
#
# Clock: 496
# Running Process: P7 Burst Time: 12
# Queue 1: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 2: ['P3([9, 26, 5, 31, 6])', 'P8([1])']
# Queue 3: []
# I/O Queue: ['P2(13)', 'P5(13)', 'P4(67)']
#
#
# Clock: 497
# Running Process: None
# Queue 1: ['P3([9, 26, 5, 31, 6])', 'P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P3([9, 26, 5, 31, 6])', 'P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(12)', 'P5(12)', 'P4(66)']
#
#
# Clock: 498
# Running Process: P3 Burst Time: 8
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(11)', 'P5(11)', 'P4(65)']
#
#
# Clock: 499
# Running Process: P3 Burst Time: 7
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(10)', 'P5(10)', 'P4(64)']
#
#
# Clock: 500
# Running Process: P3 Burst Time: 6
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(9)', 'P5(9)', 'P4(63)']
#
#
# Clock: 501
# Running Process: P3 Burst Time: 5
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(8)', 'P5(8)', 'P4(62)']
#
#
# Clock: 502
# Running Process: P3 Burst Time: 4
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(7)', 'P5(7)', 'P4(61)']
#
#
# Clock: 503
# Running Process: P3 Burst Time: 3
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(6)', 'P5(6)', 'P4(60)']
#
#
# Clock: 504
# Running Process: P3 Burst Time: 2
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(5)', 'P5(5)', 'P4(59)']
#
#
# Clock: 505
# Running Process: P3 Burst Time: 1
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(4)', 'P5(4)', 'P4(58)']
#
#
# Clock: 506
# Running Process: None
# Queue 1: ['P8([1])', 'P7([11, 33, 10])']
# Queue 2: ['P8([1])', 'P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(3)', 'P5(3)', 'P4(57)', 'P3(25)']
#
#
# Process P8 has completed its total execution.
# Clock: 507
# Running Process: None
# Queue 1: ['P7([11, 33, 10])']
# Queue 2: ['P7([11, 33, 10])']
# Queue 3: []
# I/O Queue: ['P2(2)', 'P5(2)', 'P4(56)', 'P3(24)']
#
#
# Clock: 508
# Running Process: P7 Burst Time: 10
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P2(1)', 'P5(1)', 'P4(55)', 'P3(23)']
#
#
# Clock: 509
# Running Process: P7 Burst Time: 9
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(54)', 'P3(22)']
#
#
# Clock: 510
# Running Process: P7 Burst Time: 8
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(53)', 'P3(21)']
#
#
# Clock: 511
# Running Process: P7 Burst Time: 7
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(52)', 'P3(20)']
#
#
# Clock: 512
# Running Process: P7 Burst Time: 6
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(51)', 'P3(19)']
#
#
# Clock: 513
# Running Process: P7 Burst Time: 5
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(50)', 'P3(18)']
#
#
# Clock: 514
# Running Process: P7 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(49)', 'P3(17)']
#
#
# Clock: 515
# Running Process: P7 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(48)', 'P3(16)']
#
#
# Clock: 516
# Running Process: P7 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(47)', 'P3(15)']
#
#
# Clock: 517
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(46)', 'P3(14)']
#
#
# Clock: 518
# Running Process: P2 Burst Time: 7
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(45)', 'P3(13)']
#
#
# Clock: 519
# Running Process: P2 Burst Time: 6
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(44)', 'P3(12)']
#
#
# Clock: 520
# Running Process: P2 Burst Time: 5
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(43)', 'P3(11)']
#
#
# Clock: 521
# Running Process: P2 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(42)', 'P3(10)']
#
#
# Clock: 522
# Running Process: None
# Queue 1: ['P2([3])']
# Queue 2: ['P2([3])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(41)', 'P3(9)']
#
#
# Clock: 523
# Running Process: P5 Burst Time: 10
# Queue 1: ['P2([3])']
# Queue 2: ['P2([3])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(40)', 'P3(8)']
#
#
# Clock: 524
# Running Process: P5 Burst Time: 9
# Queue 1: ['P2([3])']
# Queue 2: ['P2([3])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(39)', 'P3(7)']
#
#
# Clock: 525
# Running Process: P5 Burst Time: 8
# Queue 1: ['P2([3])']
# Queue 2: ['P2([3])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(38)', 'P3(6)']
#
#
# Clock: 526
# Running Process: P5 Burst Time: 7
# Queue 1: ['P2([3])']
# Queue 2: ['P2([3])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(37)', 'P3(5)']
#
#
# Clock: 527
# Running Process: None
# Queue 1: ['P2([3])', 'P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P2([3])', 'P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(36)', 'P3(4)']
#
#
# Clock: 528
# Running Process: P2 Burst Time: 2
# Queue 1: ['P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(35)', 'P3(3)']
#
#
# Clock: 529
# Running Process: P2 Burst Time: 1
# Queue 1: ['P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(34)', 'P3(2)']
#
#
# Process P2 has completed its total execution.
# Clock: 530
# Running Process: None
# Queue 1: ['P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 2: ['P5([6, 21, 6, 13, 3, 11, 4])']
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(33)', 'P3(1)']
#
#
# Clock: 531
# Running Process: P5 Burst Time: 5
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(32)']
#
#
# Clock: 532
# Running Process: P5 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(31)']
#
#
# Clock: 533
# Running Process: P5 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(30)']
#
#
# Clock: 534
# Running Process: P5 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(29)']
#
#
# Clock: 535
# Running Process: P5 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(28)']
#
#
# Clock: 536
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(27)', 'P5(20)']
#
#
# Clock: 537
# Running Process: P3 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(26)', 'P5(19)']
#
#
# Clock: 538
# Running Process: P3 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(25)', 'P5(18)']
#
#
# Clock: 539
# Running Process: P3 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(24)', 'P5(17)']
#
#
# Clock: 540
# Running Process: P3 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(23)', 'P5(16)']
#
#
# Clock: 541
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: ['P7([1, 33, 10])']
# I/O Queue: ['P4(22)', 'P5(15)', 'P3(30)']
#
#
# Clock: 542
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(21)', 'P5(14)', 'P3(29)', 'P7(32)']
#
#
# Clock: 543
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(20)', 'P5(13)', 'P3(28)', 'P7(31)']
#
#
# Clock: 544
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(19)', 'P5(12)', 'P3(27)', 'P7(30)']
#
#
# Clock: 545
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(18)', 'P5(11)', 'P3(26)', 'P7(29)']
#
#
# Clock: 546
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(17)', 'P5(10)', 'P3(25)', 'P7(28)']
#
#
# Clock: 547
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(16)', 'P5(9)', 'P3(24)', 'P7(27)']
#
#
# Clock: 548
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(15)', 'P5(8)', 'P3(23)', 'P7(26)']
#
#
# Clock: 549
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(14)', 'P5(7)', 'P3(22)', 'P7(25)']
#
#
# Clock: 550
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(13)', 'P5(6)', 'P3(21)', 'P7(24)']
#
#
# Clock: 551
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(12)', 'P5(5)', 'P3(20)', 'P7(23)']
#
#
# Clock: 552
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(11)', 'P5(4)', 'P3(19)', 'P7(22)']
#
#
# Clock: 553
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(10)', 'P5(3)', 'P3(18)', 'P7(21)']
#
#
# Clock: 554
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(9)', 'P5(2)', 'P3(17)', 'P7(20)']
#
#
# Clock: 555
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(8)', 'P5(1)', 'P3(16)', 'P7(19)']
#
#
# Clock: 556
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(7)', 'P3(15)', 'P7(18)']
#
#
# Clock: 557
# Running Process: P5 Burst Time: 5
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(6)', 'P3(14)', 'P7(17)']
#
#
# Clock: 558
# Running Process: P5 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(5)', 'P3(13)', 'P7(16)']
#
#
# Clock: 559
# Running Process: P5 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(4)', 'P3(12)', 'P7(15)']
#
#
# Clock: 560
# Running Process: P5 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(3)', 'P3(11)', 'P7(14)']
#
#
# Clock: 561
# Running Process: None
# Queue 1: ['P5([1, 13, 3, 11, 4])']
# Queue 2: ['P5([1, 13, 3, 11, 4])']
# Queue 3: []
# I/O Queue: ['P4(2)', 'P3(10)', 'P7(13)']
#
#
# Clock: 562
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P4(1)', 'P3(9)', 'P7(12)', 'P5(12)']
#
#
# Clock: 563
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(8)', 'P7(11)', 'P5(11)']
#
#
# Clock: 564
# Running Process: P4 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(7)', 'P7(10)', 'P5(10)']
#
#
# Clock: 565
# Running Process: P4 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(6)', 'P7(9)', 'P5(9)']
#
#
# Process P4 has completed its total execution.
# Clock: 566
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(5)', 'P7(8)', 'P5(8)']
#
#
# Clock: 567
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(4)', 'P7(7)', 'P5(7)']
#
#
# Clock: 568
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(3)', 'P7(6)', 'P5(6)']
#
#
# Clock: 569
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(2)', 'P7(5)', 'P5(5)']
#
#
# Clock: 570
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P3(1)', 'P7(4)', 'P5(4)']
#
#
# Clock: 571
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P7(3)', 'P5(3)']
#
#
# Clock: 572
# Running Process: P3 Burst Time: 5
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P7(2)', 'P5(2)']
#
#
# Clock: 573
# Running Process: P3 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P7(1)', 'P5(1)']
#
#
# Clock: 574
# Running Process: P3 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 575
# Running Process: P3 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 576
# Running Process: None
# Queue 1: ['P3([1])']
# Queue 2: ['P3([1])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 577
# Running Process: P7 Burst Time: 9
# Queue 1: ['P3([1])']
# Queue 2: ['P3([1])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 578
# Running Process: P7 Burst Time: 8
# Queue 1: ['P3([1])']
# Queue 2: ['P3([1])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 579
# Running Process: P7 Burst Time: 7
# Queue 1: ['P3([1])']
# Queue 2: ['P3([1])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 580
# Running Process: P7 Burst Time: 6
# Queue 1: ['P3([1])']
# Queue 2: ['P3([1])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 581
# Running Process: None
# Queue 1: ['P3([1])', 'P7([5])']
# Queue 2: ['P3([1])', 'P7([5])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 582
# Running Process: P5 Burst Time: 2
# Queue 1: ['P3([1])', 'P7([5])']
# Queue 2: ['P3([1])', 'P7([5])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 583
# Running Process: P5 Burst Time: 1
# Queue 1: ['P3([1])', 'P7([5])']
# Queue 2: ['P3([1])', 'P7([5])']
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 584
# Running Process: None
# Queue 1: ['P3([1])', 'P7([5])']
# Queue 2: ['P3([1])', 'P7([5])']
# Queue 3: []
# I/O Queue: ['P5(10)']
#
#
# Process P3 has completed its total execution.
# Clock: 585
# Running Process: None
# Queue 1: ['P7([5])']
# Queue 2: ['P7([5])']
# Queue 3: []
# I/O Queue: ['P5(9)']
#
#
# Clock: 586
# Running Process: P7 Burst Time: 4
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(8)']
#
#
# Clock: 587
# Running Process: P7 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(7)']
#
#
# Clock: 588
# Running Process: P7 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(6)']
#
#
# Clock: 589
# Running Process: P7 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(5)']
#
#
# Process P7 has completed its total execution.
# Clock: 590
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(4)']
#
#
# Clock: 591
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(3)']
#
#
# Clock: 592
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(2)']
#
#
# Clock: 593
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: ['P5(1)']
#
#
# Clock: 594
# Running Process: None
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 595
# Running Process: P5 Burst Time: 3
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 596
# Running Process: P5 Burst Time: 2
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Clock: 597
# Running Process: P5 Burst Time: 1
# Queue 1: []
# Queue 2: []
# Queue 3: []
# I/O Queue: []
#
#
# Process P5 has completed its total execution.
# Process	Waiting Time	Turnaround Time	Response Time
# P1	47		272		0
# P2	102		529		5
# P3	192		584		9
# P4	81		565		14
# P5	288		597		17
# P6	197		412		22
# P7	261		589		27
# P8	197		506		32
#
# Average Waiting Time: 170.625
# Average Turnaround Time: 506.75
# Average Response Time: 15.75
# CPU Utilization: 0.9247491638795987%
# Total Run Time: 598
